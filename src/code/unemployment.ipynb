# %%
import altair as alt

# %%
import pandas as pd
import numpy as np
def tab_reader(filepathpattern,tabnum,skiprow,low_memory=False):
    tabs = []
    for i in range (tabnum):
        cur_index = i+1
        cur_filepath = filepathpattern.format(cur_index)
        try:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow, low_memory=False)
        except:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow,encoding='latin-1', low_memory=low_memory)
        tabs.append(tab)
    return tabs

# %%
# 2017 data
rcbp_2017_mb_profitMargin_Tabs = tab_reader("../2017_csv_eng/2017_Medium businesses_Profit margin based_csv/_2017_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2017_mb_revenue_Tabs = tab_reader("../2017_csv_eng/2017_Medium businesses_Total revenue based_csv/_2017_Eng_Medium_Revenue_Tab{}.csv",5,5)
rcbp_2017_sb_profitMargin_Tabs = tab_reader("../2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",7,5)
rcbp_2017_sb_profitMargin_Tabs[0] = tab_reader("../2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",1,6)[0]
rcbp_2017_sb_revenue_Tabs = tab_reader("../2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",7,5)
rcbp_2017_sb_revenue_Tabs[0] = tab_reader("../2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",1,6)[0]

# %%
# 2018 data
rcbp_2018_mb_profitMargin_Tabs = tab_reader("../2018_csv_eng/2018_Medium businesses_Profit margin based_csv/_2018_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2018_mb_revenue_Tabs = tab_reader("../2018_csv_eng/2018_Medium businesses_Total revenue based_csv/_2018_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2018_sb_profitMargin_Tabs = tab_reader("../2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2018_sb_profitMargin_Tabs[0] = tab_reader("../2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2018_sb_revenue_Tabs = tab_reader("../2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2018_sb_revenue_Tabs[0] = tab_reader("../2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
# 2019 data
rcbp_2019_mb_profitMargin_Tabs = tab_reader("../2019_csv_eng/2019_Medium businesses_Profit margin_csv/_2019_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2019_mb_revenue_Tabs = tab_reader("../2019_csv_eng/2019_Medium businesses_Total revenue_csv/_2019_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2019_sb_profitMargin_Tabs = tab_reader("../2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2019_sb_profitMargin_Tabs[0] = tab_reader("../2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2019_sb_revenue_Tabs = tab_reader("../2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2019_sb_revenue_Tabs[0] = tab_reader("../2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
def selectData(tabs):
    concatTabs = []
    for tab in tabs:
        cols_without_quartile = [x for x in tab.columns if 'quartile' not in x.lower()]
        tab = tab[cols_without_quartile]
        tab = tab.loc[(tab["North American Industry Classification System, NAICS - code"] == '0')]
        concatTabs.append(tab)
    return pd.concat(concatTabs)

# %%
mb_2017_revenue_tab3 = rcbp_2017_mb_revenue_Tabs[2]
mb_2018_revenue_tab3 = rcbp_2018_mb_revenue_Tabs[2]
mb_2019_revenue_tab3 = rcbp_2019_mb_revenue_Tabs[2]
mb_expenses_value_3y = selectData([mb_2017_revenue_tab3,mb_2018_revenue_tab3,mb_2019_revenue_tab3])

# %%
mb_2017_revenue_tab1 = rcbp_2017_mb_revenue_Tabs[0]
mb_2018_revenue_tab1 = rcbp_2018_mb_revenue_Tabs[0]
mb_2019_revenue_tab1 = rcbp_2019_mb_revenue_Tabs[0]
mb_count_3y = selectData([mb_2017_revenue_tab1,mb_2018_revenue_tab1,mb_2019_revenue_tab1])

# %%
mb_2017_revenue_tab5 = rcbp_2017_mb_revenue_Tabs[4]
mb_2018_revenue_tab5 = rcbp_2018_mb_revenue_Tabs[4]
mb_2019_revenue_tab5 = rcbp_2019_mb_revenue_Tabs[4]
mb_debt_3y = selectData([mb_2017_revenue_tab5,mb_2018_revenue_tab5,mb_2019_revenue_tab5])

# %%
mb_2017_revenue_tab4 = rcbp_2017_mb_revenue_Tabs[3]
mb_2018_revenue_tab4 = rcbp_2018_mb_revenue_Tabs[3]
mb_2019_revenue_tab4 = rcbp_2019_mb_revenue_Tabs[3]
mb_equity_3y = selectData([mb_2017_revenue_tab4,mb_2018_revenue_tab4,mb_2019_revenue_tab4])

# %%
sb_2017_revenue_tab3 = rcbp_2017_sb_revenue_Tabs[2]
sb_2018_revenue_tab3 = rcbp_2018_sb_revenue_Tabs[2]
sb_2019_revenue_tab3 = rcbp_2019_sb_revenue_Tabs[2]
sb_revenue_value_3y = selectData([sb_2017_revenue_tab3,sb_2018_revenue_tab3,sb_2019_revenue_tab3])

# %%
sb_2017_revenue_tab7 = rcbp_2017_sb_revenue_Tabs[6]
sb_2018_revenue_tab7 = rcbp_2018_sb_revenue_Tabs[6]
sb_2019_revenue_tab7 = rcbp_2019_sb_revenue_Tabs[6]
sb_profitable_3y = selectData([sb_2017_revenue_tab7,sb_2018_revenue_tab7,sb_2019_revenue_tab7])

# %%
sb_2017_revenue_tab1 = rcbp_2017_sb_revenue_Tabs[0]
sb_2018_revenue_tab1 = rcbp_2018_sb_revenue_Tabs[0]
sb_2019_revenue_tab1 = rcbp_2019_sb_revenue_Tabs[0]
sb_count_3y = selectData([sb_2017_revenue_tab1,sb_2018_revenue_tab1,sb_2019_revenue_tab1])

# %%
sb_2017_revenue_tab5 = rcbp_2017_sb_revenue_Tabs[4]
sb_2018_revenue_tab5 = rcbp_2018_sb_revenue_Tabs[4]
sb_2019_revenue_tab5 = rcbp_2019_sb_revenue_Tabs[4]
sb_debt_3y = selectData([sb_2017_revenue_tab5,sb_2018_revenue_tab5,sb_2019_revenue_tab5])

# %%
sb_2017_revenue_tab4 = rcbp_2017_sb_revenue_Tabs[3]
sb_2018_revenue_tab4 = rcbp_2018_sb_revenue_Tabs[3]
sb_2019_revenue_tab4 = rcbp_2019_sb_revenue_Tabs[3]
sb_equity_3y = selectData([sb_2017_revenue_tab4,sb_2018_revenue_tab4,sb_2019_revenue_tab4])

# %% [markdown]
# # Unemployment Rate

# %%
unemployment_rate_df = pd.read_csv('unemployment_rate.csv')
unemployment_rate_df
# Out:
#     REF_DATE                        GEO Labour force characteristics  \
# 0       2017  Newfoundland and Labrador            Unemployment rate
# 1       2017  Newfoundland and Labrador            Unemployment rate
# 2       2017       Prince Edward Island            Unemployment rate
# 3       2017       Prince Edward Island            Unemployment rate
# 4       2017                Nova Scotia            Unemployment rate
# 5       2017                Nova Scotia            Unemployment rate
# 6       2017              New Brunswick            Unemployment rate
# 7       2017              New Brunswick            Unemployment rate
# 8       2017                     Quebec            Unemployment rate
# 9       2017                     Quebec            Unemployment rate
# 10      2017                    Ontario            Unemployment rate
# 11      2017                    Ontario            Unemployment rate
# 12      2017                   Manitoba            Unemployment rate
# ...

# %%
unemployment_rate_df = unemployment_rate_df.rename(columns={'Population centre and rural areas':'Location indicator','REF_DATE':'Reference year','GEO':'Geography','VALUE':'unemployment_rate'})
unemployment_rate_df.loc[unemployment_rate_df['Location indicator'] == 'Census metropolitan area and census agglomeration', 'Location indicator'] = 'Urban'
unemployment_rate_df.loc[unemployment_rate_df['Location indicator'] == 'Non-census metropolitan area and non-census agglomeration', 'Location indicator'] = 'Rural'
unemployment_rate_df.loc[unemployment_rate_df['Geography'] == 'Quebec', 'Geography'] = 'Québec'
unemployment_rate_df
# Out:
#     Reference year                  Geography Labour force characteristics  \
# 0             2017  Newfoundland and Labrador            Unemployment rate
# 1             2017  Newfoundland and Labrador            Unemployment rate
# 2             2017       Prince Edward Island            Unemployment rate
# 3             2017       Prince Edward Island            Unemployment rate
# 4             2017                Nova Scotia            Unemployment rate
# 5             2017                Nova Scotia            Unemployment rate
# 6             2017              New Brunswick            Unemployment rate
# 7             2017              New Brunswick            Unemployment rate
# 8             2017                     Québec            Unemployment rate
# 9             2017                     Québec            Unemployment rate
# 10            2017                    Ontario            Unemployment rate
# ...

# %%
unemployment_rate_CA_df = pd.read_csv('unemployment_rate_canada.csv')
unemployment_rate_CA_df
# Out:
#    REF_DATE     GEO           DGUID Labour force characteristics  \
# 0      2017  Canada  2016A000011124            Unemployment rate
# 1      2017  Canada  2016A000011124            Unemployment rate
# 2      2018  Canada  2016A000011124            Unemployment rate
# 3      2018  Canada  2016A000011124            Unemployment rate
# 4      2019  Canada  2016A000011124            Unemployment rate
# 5      2019  Canada  2016A000011124            Unemployment rate
#
#                    Population centre and rural areas         Sex  \
# 0  Census metropolitan area and census agglomeration  Both sexes
# 1  Non-census metropolitan area and non-census ag...  Both sexes
# 2  Census metropolitan area and census agglomeration  Both sexes
# 3  Non-census metropolitan area and non-census ag...  Both sexes
# 4  Census metropolitan area and census agglomeration  Both sexes
# 5  Non-census metropolitan area and non-census ag...  Both sexes
#
#            Age group  VALUE
# ...

# %%
unemployment_rate_CA_df = unemployment_rate_CA_df.rename(columns={'Population centre and rural areas':'Location indicator','REF_DATE':'Reference year','GEO':'Geography','VALUE':'unemployment_rate'})

# %%
unemployment_rate_CA_df.loc[unemployment_rate_CA_df['Location indicator'] == 'Census metropolitan area and census agglomeration', 'Location indicator'] = 'Urban'
unemployment_rate_CA_df.loc[unemployment_rate_CA_df['Location indicator'] == 'Non-census metropolitan area and non-census agglomeration', 'Location indicator'] = 'Rural'
unemployment_rate_CA_df
# Out:
#    Reference year Geography           DGUID Labour force characteristics  \
# 0            2017    Canada  2016A000011124            Unemployment rate
# 1            2017    Canada  2016A000011124            Unemployment rate
# 2            2018    Canada  2016A000011124            Unemployment rate
# 3            2018    Canada  2016A000011124            Unemployment rate
# 4            2019    Canada  2016A000011124            Unemployment rate
# 5            2019    Canada  2016A000011124            Unemployment rate
#
#   Location indicator         Sex          Age group  unemployment_rate
# 0              Urban  Both sexes  15 years and over                6.3
# 1              Rural  Both sexes  15 years and over                7.0
# 2              Urban  Both sexes  15 years and over                5.8
# 3              Rural  Both sexes  15 years and over                6.5
# 4              Urban  Both sexes  15 years and over                5.7
# ...

# %% [markdown]
# # Medium Business

# %% [markdown]
# ## Net Profit

# %%
mb_expenses_value_3y
# Out:
#     ID North American Industry Classification System, NAICS - code  \
# 1  1.0                                                  0
# 2  2.0                                                  0
# 1  1.0                                                  0
# 2  2.0                                                  0
# 1  1.0                                                  0
# 2  2.0                                                  0
#
#   North American Industry Classification System, NAICS  Geography - code  \
# 1                                     All industries                 0.0
# 2                                     All industries                 0.0
# 1                                     All industries                 0.0
# 2                                     All industries                 0.0
# 1                                     All industries                 0.0
# 2                                     All industries                 0.0
#
# ...

# %%
mb_expenses_value_3y = mb_expenses_value_3y[['Geography','Location indicator - code', 'Location indicator', 'Incorporation status', 'Reference year', 'Net Profit/Loss', 'Labour and commissions']]
mb_expenses_value_3y['Reference year'] = mb_expenses_value_3y['Reference year'].astype(int)
mb_expenses_value_3y
# Out:
# C:\Users\BOWENY~1\AppData\Local\Temp/ipykernel_91388/778448727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mb_expenses_value_3y['Reference year'] = mb_expenses_value_3y['Reference year'].astype(int)
#   Geography  Location indicator - code Location indicator  \
# 1    Canada                        1.0              Rural
# 2    Canada                        2.0              Urban
# 1    Canada                        1.0              Rural
# 2    Canada                        2.0              Urban
# 1    Canada                        1.0              Rural
# 2    Canada                        2.0              Urban
#
#   Incorporation status  Reference year Net Profit/Loss Labour and commissions
# ...

# %%
mb_merged_df = pd.merge(mb_expenses_value_3y,unemployment_rate_CA_df,how='inner',on=['Geography', 'Location indicator', 'Reference year'])
mb_merged_df
# Out:
#   Geography  Location indicator - code Location indicator  \
# 0    Canada                        1.0              Rural
# 1    Canada                        2.0              Urban
# 2    Canada                        1.0              Rural
# 3    Canada                        2.0              Urban
# 4    Canada                        1.0              Rural
# 5    Canada                        2.0              Urban
#
#   Incorporation status  Reference year Net Profit/Loss Labour and commissions  \
# 0         Incorporated            2017           362.8                    983
# 1         Incorporated            2017           605.9                 1303.9
# 2         Incorporated            2018           348.2                  976.7
# 3         Incorporated            2018           675.5                 1316.3
# 4         Incorporated            2019           332.7                  998.4
# 5         Incorporated            2019           674.3                 1340.4
#
# ...

# %%
mb_merged_df = mb_merged_df[['Geography','Location indicator - code','Location indicator','Reference year','Net Profit/Loss','unemployment_rate']]

# %%
mb_merged_df
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 0    Canada                        1.0              Rural            2017
# 1    Canada                        2.0              Urban            2017
# 2    Canada                        1.0              Rural            2018
# 3    Canada                        2.0              Urban            2018
# 4    Canada                        1.0              Rural            2019
# 5    Canada                        2.0              Urban            2019
#
#   Net Profit/Loss  unemployment_rate
# 0           362.8                7.0
# 1           605.9                6.3
# 2           348.2                6.5
# 3           675.5                5.8
# 4           332.7                6.2
# 5           674.3                5.7

# %%
# mb_merged_df.to_csv("mb_merged_unemployment_rate.csv", index=False)

# %%
alt.Chart(mb_merged_df[mb_merged_df['Location indicator'] == 'Urban']).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(mb_merged_df[mb_merged_df['Location indicator'] == 'Rural']).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(mb_merged_df).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Total business count

# %%
mb_count_3y = mb_count_3y[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'Total number of businesses']] # Labour and commissions cost
mb_count_3y['Reference year'] = mb_count_3y['Reference year'].astype(int)

# %%
mb_count_3y
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 1    Canada                        1.0              Rural            2017
# 2    Canada                        2.0              Urban            2017
# 1    Canada                        1.0              Rural            2018
# 2    Canada                        2.0              Urban            2018
# 1    Canada                        1.0              Rural            2019
# 2    Canada                        2.0              Urban            2019
#
#   Total number of businesses
# 1                       6901
# 2                      40390
# 1                       7434
# 2                      42801
# 1                       7446
# 2                      43823

# %%
mb_merged_df = pd.merge(mb_merged_df,mb_count_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year', 'Location indicator - code'])
mb_merged_df
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 0    Canada                        1.0              Rural            2017
# 1    Canada                        2.0              Urban            2017
# 2    Canada                        1.0              Rural            2018
# 3    Canada                        2.0              Urban            2018
# 4    Canada                        1.0              Rural            2019
# 5    Canada                        2.0              Urban            2019
#
#   Net Profit/Loss  unemployment_rate Total number of businesses
# 0           362.8                7.0                       6901
# 1           605.9                6.3                      40390
# 2           348.2                6.5                       7434
# 3           675.5                5.8                      42801
# 4           332.7                6.2                       7446
# 5           674.3                5.7                      43823

# %%
alt.Chart(mb_merged_df).mark_point().encode(
    x=alt.X('Total number of businesses:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
# alt.Chart(mb_merged_df).mark_point().encode(
#     x=alt.X('Labour and commissions', title=''),
#     y=alt.Y('unemployment_rate:Q')
# ).properties(width=600, height=300)

# %% [markdown]
# ## Debt and current ratio

# %%
mb_debt_3y = mb_debt_3y[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'Current ratio (times)', 'Debt to equity ratio (times)', 'Debt ratio (times)', 'Current debt to equity (%)']] # Labour and commissions cost
mb_debt_3y['Reference year'] = mb_debt_3y['Reference year'].astype(int)

# %%
mb_debt_3y
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 1    Canada                        1.0              Rural            2017
# 2    Canada                        2.0              Urban            2017
# 1    Canada                        1.0              Rural            2018
# 2    Canada                        2.0              Urban            2018
# 1    Canada                        1.0              Rural            2019
# 2    Canada                        2.0              Urban            2019
#
#   Current ratio (times) Debt to equity ratio (times) Debt ratio (times)  \
# 1                   1.4                          1.3                0.6
# 2                   1.5                          1.1                0.5
# 1                   1.4                          1.3                0.6
# 2                   1.5                          1.2                0.6
# 1                   1.4                          1.4                0.6
# ...

# %%
mb_merged_df = pd.merge(mb_merged_df,mb_debt_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Location indicator - code'])
mb_merged_df
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 0    Canada                        1.0              Rural            2017
# 1    Canada                        2.0              Urban            2017
# 2    Canada                        1.0              Rural            2018
# 3    Canada                        2.0              Urban            2018
# 4    Canada                        1.0              Rural            2019
# 5    Canada                        2.0              Urban            2019
#
#   Net Profit/Loss  unemployment_rate Total number of businesses  \
# 0           362.8                7.0                       6901
# 1           605.9                6.3                      40390
# 2           348.2                6.5                       7434
# 3           675.5                5.8                      42801
# 4           332.7                6.2                       7446
# ...

# %%
alt.Chart(mb_merged_df).mark_point().encode(
    x=alt.X('Current ratio (times):Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(mb_merged_df).mark_point().encode(
    x=alt.X('Debt to equity ratio (times):Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Equity

# %%
mb_equity_3y = mb_equity_3y[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'Total equity']]
mb_equity_3y['Reference year'] = mb_equity_3y['Reference year'].astype(int)

# %%
mb_equity_3y
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 1    Canada                        1.0              Rural            2017
# 2    Canada                        2.0              Urban            2017
# 1    Canada                        1.0              Rural            2018
# 2    Canada                        2.0              Urban            2018
# 1    Canada                        1.0              Rural            2019
# 2    Canada                        2.0              Urban            2019
#
#   Total equity
# 1       3190.6
# 2       5509.8
# 1       3061.2
# 2       5237.7
# 1       3064.8
# 2       5732.4

# %%
mb_merged_df = pd.merge(mb_merged_df,mb_equity_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Location indicator - code'])
mb_merged_df
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 0    Canada                        1.0              Rural            2017
# 1    Canada                        2.0              Urban            2017
# 2    Canada                        1.0              Rural            2018
# 3    Canada                        2.0              Urban            2018
# 4    Canada                        1.0              Rural            2019
# 5    Canada                        2.0              Urban            2019
#
#   Net Profit/Loss  unemployment_rate Total number of businesses  \
# 0           362.8                7.0                       6901
# 1           605.9                6.3                      40390
# 2           348.2                6.5                       7434
# 3           675.5                5.8                      42801
# 4           332.7                6.2                       7446
# ...

# %%
alt.Chart(mb_merged_df).mark_point().encode(
    x=alt.X('Total equity:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Export to csv files

# %%
mb_merged_df['Location indicator - code'] = mb_merged_df['Location indicator - code'] - 1

# %%
mb_merged_rural = mb_merged_df[mb_merged_df['Location indicator']=='Rural' ]
mb_merged_rural
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 0    Canada                        0.0              Rural            2017
# 2    Canada                        0.0              Rural            2018
# 4    Canada                        0.0              Rural            2019
#
#   Net Profit/Loss  unemployment_rate Total number of businesses  \
# 0           362.8                7.0                       6901
# 2           348.2                6.5                       7434
# 4           332.7                6.2                       7446
#
#   Current ratio (times) Debt to equity ratio (times) Debt ratio (times)  \
# 0                   1.4                          1.3                0.6
# 2                   1.4                          1.3                0.6
# 4                   1.4                          1.4                0.6
#
#   Current debt to equity (%) Total equity
# 0                       71.9       3190.6
# ...

# %%
mb_merged_urban = mb_merged_df[mb_merged_df['Location indicator']=='Urban' ]
mb_merged_urban
# Out:
#   Geography  Location indicator - code Location indicator  Reference year  \
# 1    Canada                        1.0              Urban            2017
# 3    Canada                        1.0              Urban            2018
# 5    Canada                        1.0              Urban            2019
#
#   Net Profit/Loss  unemployment_rate Total number of businesses  \
# 1           605.9                6.3                      40390
# 3           675.5                5.8                      42801
# 5           674.3                5.7                      43823
#
#   Current ratio (times) Debt to equity ratio (times) Debt ratio (times)  \
# 1                   1.5                          1.1                0.5
# 3                   1.5                          1.2                0.6
# 5                   1.5                          1.2                0.5
#
#   Current debt to equity (%) Total equity
# 1                       56.5       5509.8
# ...

# %%
mb_merged_df.to_csv("mb_merged_unemployment_rate_all_new.csv", index=False)

mb_merged_rural.to_csv("mb_merged_unemployment_rate_rural_new.csv", index=False)
mb_merged_urban.to_csv("mb_merged_unemployment_rate_urban_new.csv", index=False)

# %% [markdown]
# # Small Business

# %% [markdown]
# ## Net Profit

# %%
sb_revenue_value_3y = sb_revenue_value_3y[['Geography','Location indicator - code', 'Location indicator', 'Incorporation status', 'Reference year', 'Net Profit/Loss', 'Labour and commissions']] # Labour and commissions cost
sb_revenue_value_3y = sb_revenue_value_3y[(sb_revenue_value_3y['Incorporation status'] == 'All businesses')]
sb_revenue_value_3y['Reference year'] = sb_revenue_value_3y['Reference year'].astype(int)

# %%
rm_geo = list(['Altantic', 'Prairies', 'Territories','Canada'])
sb_revenue_value_3y = sb_revenue_value_3y.loc[~sb_revenue_value_3y.Geography.isin(rm_geo)]

# %%
sb_revenue_value_3y
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 15  Newfoundland and Labrador                        1.0              Rural
# 18  Newfoundland and Labrador                        2.0              Urban
# 21       Prince Edward Island                        1.0              Rural
# 24       Prince Edward Island                        2.0              Urban
# 27                Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 87                      Yukon                        1.0              Rural
# 90                      Yukon                        2.0              Urban
# 93       Nordwest Territories                        1.0              Rural
# 96       Nordwest Territories                        2.0              Urban
# 99                    Nunavut                        1.0              Rural
#
# ...

# %% [markdown]
# ## Profitable

# %%
sb_profitable_3y = sb_profitable_3y[['Geography','Location indicator - code', 'Location indicator', 'Incorporation status', 'Reference year', 'Percent of profitable businesses']]
sb_profitable_3y['Reference year'] = sb_profitable_3y['Reference year'].astype(int)

# %%
sb_profitable_3y = sb_profitable_3y.loc[~sb_profitable_3y.Geography.isin(rm_geo)]

# %%
sb_profitable_3y
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 5   Newfoundland and Labrador                        1.0              Rural
# 6   Newfoundland and Labrador                        2.0              Urban
# 7        Prince Edward Island                        1.0              Rural
# 8        Prince Edward Island                        2.0              Urban
# 9                 Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 29                      Yukon                        1.0              Rural
# 30                      Yukon                        2.0              Urban
# 31       Nordwest Territories                        1.0              Rural
# 32       Nordwest Territories                        2.0              Urban
# 33                    Nunavut                        1.0              Rural
#
# ...

# %%
sb_merged_df = pd.merge(sb_revenue_value_3y,sb_profitable_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Incorporation status','Location indicator - code'])
sb_merged_df
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        1.0              Rural
# 1   Newfoundland and Labrador                        2.0              Urban
# 2        Prince Edward Island                        1.0              Rural
# 3        Prince Edward Island                        2.0              Urban
# 4                 Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 70                      Yukon                        1.0              Rural
# 71                      Yukon                        2.0              Urban
# 72       Nordwest Territories                        1.0              Rural
# 73       Nordwest Territories                        2.0              Urban
# 74                    Nunavut                        1.0              Rural
#
# ...

# %%
unemployment_rate_df = unemployment_rate_df.loc[~unemployment_rate_df.Geography.isin(rm_geo)]
unemployment_rate_df
# Out:
#     Reference year                  Geography Labour force characteristics  \
# 0             2017  Newfoundland and Labrador            Unemployment rate
# 1             2017  Newfoundland and Labrador            Unemployment rate
# 2             2017       Prince Edward Island            Unemployment rate
# 3             2017       Prince Edward Island            Unemployment rate
# 4             2017                Nova Scotia            Unemployment rate
# 5             2017                Nova Scotia            Unemployment rate
# 6             2017              New Brunswick            Unemployment rate
# 7             2017              New Brunswick            Unemployment rate
# 8             2017                     Québec            Unemployment rate
# 9             2017                     Québec            Unemployment rate
# 10            2017                    Ontario            Unemployment rate
# ...

# %%
unemployment_rate_df.Geography.unique()
# Out:
# array(['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
#        'New Brunswick', 'Québec', 'Ontario', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia'], dtype=object)

# %%
sb_merged_df.Geography.unique()
# Out:
# array(['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
#        'New Brunswick', 'Québec', 'Ontario', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia', 'Yukon', 'Nordwest Territories',
#        'Nunavut'], dtype=object)

# %%
sb_merged_df = pd.merge(sb_merged_df,unemployment_rate_df,how='inner',on=['Geography', 'Location indicator', 'Reference year'])
sb_merged_df
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        1.0              Rural
# 1   Newfoundland and Labrador                        2.0              Urban
# 2        Prince Edward Island                        1.0              Rural
# 3        Prince Edward Island                        2.0              Urban
# 4                 Nova Scotia                        1.0              Rural
# 5                 Nova Scotia                        2.0              Urban
# 6               New Brunswick                        1.0              Rural
# 7               New Brunswick                        2.0              Urban
# 8                      Québec                        1.0              Rural
# 9                      Québec                        2.0              Urban
# 10                    Ontario                        1.0              Rural
# ...

# %%
# sb_merged_df.to_csv("sb_merged_unemployment_rate.csv", index=False)

# %%
alt.Chart(sb_merged_df[sb_merged_df['Location indicator'] == 'Urban']).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df[sb_merged_df['Location indicator'] == 'Rural']).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Net Profit/Loss:Q',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Percent of profitable businesses:Q',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df[sb_merged_df['Location indicator'] == 'Urban']).mark_point().encode(
    x=alt.X('Percent of profitable businesses:Q',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df[sb_merged_df['Location indicator'] == 'Rural']).mark_point().encode(
    x=alt.X('Percent of profitable businesses:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Total business count

# %%
sb_count_3y = sb_count_3y[['Geography','Location indicator - code', 'Location indicator', 'Incorporation status', 'Reference year', 'Total number of businesses']] # Labour and commissions cost
sb_count_3y = sb_count_3y[(sb_count_3y['Incorporation status'] == 'All businesses')]
sb_count_3y['Reference year'] = sb_count_3y['Reference year'].astype(int)

# %%
sb_count_3y = sb_count_3y.loc[~sb_count_3y.Geography.isin(rm_geo)]

# %%
sb_count_3y
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 15  Newfoundland and Labrador                        1.0              Rural
# 18  Newfoundland and Labrador                        2.0              Urban
# 21       Prince Edward Island                        1.0              Rural
# 24       Prince Edward Island                        2.0              Urban
# 27                Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 87                      Yukon                        1.0              Rural
# 90                      Yukon                        2.0              Urban
# 93       Nordwest Territories                        1.0              Rural
# 96       Nordwest Territories                        2.0              Urban
# 99                    Nunavut                        1.0              Rural
#
# ...

# %%
sb_merged_df = pd.merge(sb_merged_df,sb_count_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Incorporation status','Location indicator - code'])
sb_merged_df
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        1.0              Rural
# 1   Newfoundland and Labrador                        2.0              Urban
# 2        Prince Edward Island                        1.0              Rural
# 3        Prince Edward Island                        2.0              Urban
# 4                 Nova Scotia                        1.0              Rural
# 5                 Nova Scotia                        2.0              Urban
# 6               New Brunswick                        1.0              Rural
# 7               New Brunswick                        2.0              Urban
# 8                      Québec                        1.0              Rural
# 9                      Québec                        2.0              Urban
# 10                    Ontario                        1.0              Rural
# ...

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Total number of businesses:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Labour and commissions:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Debt and current ratio

# %%
sb_debt_3y = sb_debt_3y[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'Current ratio (times)', 'Debt to equity ratio (times)', 'Debt ratio (times)', 'Current debt to equity (%)']] # Labour and commissions cost
sb_debt_3y['Reference year'] = sb_debt_3y['Reference year'].astype(int)

# %%
sb_debt_3y = sb_debt_3y.loc[~sb_debt_3y.Geography.isin(rm_geo)]

# %%
sb_debt_3y
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 5   Newfoundland and Labrador                        1.0              Rural
# 6   Newfoundland and Labrador                        2.0              Urban
# 7        Prince Edward Island                        1.0              Rural
# 8        Prince Edward Island                        2.0              Urban
# 9                 Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 29                      Yukon                        1.0              Rural
# 30                      Yukon                        2.0              Urban
# 31       Nordwest Territories                        1.0              Rural
# 32       Nordwest Territories                        2.0              Urban
# 33                    Nunavut                        1.0              Rural
#
# ...

# %%
sb_merged_df = pd.merge(sb_merged_df,sb_debt_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Location indicator - code'])
sb_merged_df
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        1.0              Rural
# 1   Newfoundland and Labrador                        2.0              Urban
# 2        Prince Edward Island                        1.0              Rural
# 3        Prince Edward Island                        2.0              Urban
# 4                 Nova Scotia                        1.0              Rural
# 5                 Nova Scotia                        2.0              Urban
# 6               New Brunswick                        1.0              Rural
# 7               New Brunswick                        2.0              Urban
# 8                      Québec                        1.0              Rural
# 9                      Québec                        2.0              Urban
# 10                    Ontario                        1.0              Rural
# ...

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Current ratio (times):Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Debt to equity ratio (times):Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Equity

# %%
sb_equity_3y = sb_equity_3y[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'Total equity']]
sb_equity_3y['Reference year'] = sb_equity_3y['Reference year'].astype(int)

# %%
sb_equity_3y = sb_equity_3y.loc[~sb_equity_3y.Geography.isin(rm_geo)]

# %%
sb_equity_3y
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 5   Newfoundland and Labrador                        1.0              Rural
# 6   Newfoundland and Labrador                        2.0              Urban
# 7        Prince Edward Island                        1.0              Rural
# 8        Prince Edward Island                        2.0              Urban
# 9                 Nova Scotia                        1.0              Rural
# ..                        ...                        ...                ...
# 29                      Yukon                        1.0              Rural
# 30                      Yukon                        2.0              Urban
# 31       Nordwest Territories                        1.0              Rural
# 32       Nordwest Territories                        2.0              Urban
# 33                    Nunavut                        1.0              Rural
#
#     Reference year Total equity
# ...

# %%
sb_merged_df = pd.merge(sb_merged_df,sb_equity_3y,how='inner',on=['Geography', 'Location indicator', 'Reference year','Location indicator - code'])
sb_merged_df
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        1.0              Rural
# 1   Newfoundland and Labrador                        2.0              Urban
# 2        Prince Edward Island                        1.0              Rural
# 3        Prince Edward Island                        2.0              Urban
# 4                 Nova Scotia                        1.0              Rural
# 5                 Nova Scotia                        2.0              Urban
# 6               New Brunswick                        1.0              Rural
# 7               New Brunswick                        2.0              Urban
# 8                      Québec                        1.0              Rural
# 9                      Québec                        2.0              Urban
# 10                    Ontario                        1.0              Rural
# ...

# %%
alt.Chart(sb_merged_df).mark_point().encode(
    x=alt.X('Total equity:Q', title='',scale=alt.Scale(zero=False)),
    y=alt.Y('unemployment_rate:Q')
).properties(width=600, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Export to csv files

# %%
sb_merged_df['Location indicator - code'] = sb_merged_df['Location indicator - code'] - 1

# %%
sb_merged_df[sb_merged_df['unemployment_rate']>10.5 ]#[['Geography','Location indicator - code', 'Location indicator', 'Reference year', 'unemployment_rate']]
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        0.0              Rural
# 2        Prince Edward Island                        0.0              Rural
# 6               New Brunswick                        0.0              Rural
# 20  Newfoundland and Labrador                        0.0              Rural
# 22       Prince Edward Island                        0.0              Rural
# 26              New Brunswick                        0.0              Rural
# 40  Newfoundland and Labrador                        0.0              Rural
# 42       Prince Edward Island                        0.0              Rural
# 46              New Brunswick                        0.0              Rural
#
#    Incorporation status  Reference year Net Profit/Loss  \
# 0        All businesses            2017            35.5
# 2        All businesses            2017            38.4
# ...

# %%
sb_merged_rm_outlier = sb_merged_df[sb_merged_df['unemployment_rate']<=10.5 ]

# %%
sb_merged_rm_outlier
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 1   Newfoundland and Labrador                        1.0              Urban
# 3        Prince Edward Island                        1.0              Urban
# 4                 Nova Scotia                        0.0              Rural
# 5                 Nova Scotia                        1.0              Urban
# 7               New Brunswick                        1.0              Urban
# 8                      Québec                        0.0              Rural
# 9                      Québec                        1.0              Urban
# 10                    Ontario                        0.0              Rural
# 11                    Ontario                        1.0              Urban
# 12                   Manitoba                        0.0              Rural
# 13                   Manitoba                        1.0              Urban
# ...

# %%
sb_merged_rural = sb_merged_df[sb_merged_df['Location indicator']=='Rural' ]
sb_merged_rural
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 0   Newfoundland and Labrador                        0.0              Rural
# 2        Prince Edward Island                        0.0              Rural
# 4                 Nova Scotia                        0.0              Rural
# 6               New Brunswick                        0.0              Rural
# 8                      Québec                        0.0              Rural
# 10                    Ontario                        0.0              Rural
# 12                   Manitoba                        0.0              Rural
# 14               Saskatchewan                        0.0              Rural
# 16                    Alberta                        0.0              Rural
# 18           British Columbia                        0.0              Rural
# 20  Newfoundland and Labrador                        0.0              Rural
# ...

# %%
sb_merged_urban = sb_merged_df[sb_merged_df['Location indicator']=='Urban' ]
sb_merged_urban
# Out:
#                     Geography  Location indicator - code Location indicator  \
# 1   Newfoundland and Labrador                        1.0              Urban
# 3        Prince Edward Island                        1.0              Urban
# 5                 Nova Scotia                        1.0              Urban
# 7               New Brunswick                        1.0              Urban
# 9                      Québec                        1.0              Urban
# 11                    Ontario                        1.0              Urban
# 13                   Manitoba                        1.0              Urban
# 15               Saskatchewan                        1.0              Urban
# 17                    Alberta                        1.0              Urban
# 19           British Columbia                        1.0              Urban
# 21  Newfoundland and Labrador                        1.0              Urban
# ...

# %%
sb_merged_rural_rm = sb_merged_rm_outlier[sb_merged_rm_outlier['Location indicator']=='Rural' ]
len(sb_merged_rural_rm)
# Out:
# 21

# %%
sb_merged_urban_rm = sb_merged_rm_outlier[sb_merged_rm_outlier['Location indicator']=='Urban' ]
len(sb_merged_urban_rm)
# Out:
# 30

# %%
sb_merged_df.to_csv("sb_merged_unemployment_rate_all_new.csv", index=False)
sb_merged_rm_outlier.to_csv("sb_merged_unemployment_rate_rm_new.csv", index=False)
sb_merged_rural.to_csv("sb_merged_unemployment_rate_rural_new.csv", index=False)
sb_merged_urban.to_csv("sb_merged_unemployment_rate_urban_new.csv", index=False)
sb_merged_rural_rm.to_csv("sb_merged_unemployment_rate_rm_rural_new.csv", index=False)
sb_merged_urban_rm.to_csv("sb_merged_unemployment_rate_rm_urban_new.csv", index=False)

# %%
population_df = pd.read_csv('population.csv')

# %%
population_df = population_df.rename(columns={'GEO':'Geography','Population and dwelling counts (3): Population, 2021 [1]':'population'})
population_df.loc[population_df['Geography'] == 'Quebec', 'Geography'] = 'Québec'
# population_df =

# %%
population_df = population_df[['Geography','population']]

# %%
population_df
# Out:
#                     Geography  population
# 0                      Canada     5957695
# 1                      Québec     1548322
# 2                     Ontario     1424102
# 3                     Alberta      752669
# 4            British Columbia      523131
# 5                Saskatchewan      385426
# 6                    Manitoba      376441
# 7                 Nova Scotia      297879
# 8               New Brunswick      285560
# 9   Newfoundland and Labrador      240942
# 10       Prince Edward Island       57316
# 11                    Nunavut       36858
# 12      Northwest Territories       20730
# 13                      Yukon        8319

# %%
temp_df = pd.merge(sb_merged_rural,population_df,how='inner',on=['Geography'])

# %%
temp_df = temp_df[['Geography','Reference year','population','Total number of businesses']]

# %%
temp_df['rate'] = temp_df['population'].astype(float)/temp_df['Total number of businesses'].astype(float)

# %%
temp_df.sort_values(by = ['rate'], ascending=False)
# Out:
#                     Geography  Reference year  population  \
# 0   Newfoundland and Labrador            2017      240942
# 1   Newfoundland and Labrador            2018      240942
# 2   Newfoundland and Labrador            2019      240942
# 9               New Brunswick            2017      285560
# 10              New Brunswick            2018      285560
# 11              New Brunswick            2019      285560
# 18                   Manitoba            2017      376441
# 20                   Manitoba            2019      376441
# 19                   Manitoba            2018      376441
# 15                    Ontario            2017     1424102
# 6                 Nova Scotia            2017      297879
# 16                    Ontario            2018     1424102
# 17                    Ontario            2019     1424102
# 7                 Nova Scotia            2018      297879
# 8                 Nova Scotia            2019      297879
# ...
