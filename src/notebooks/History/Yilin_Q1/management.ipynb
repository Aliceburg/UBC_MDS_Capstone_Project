# %%
import pandas as pd
import numpy as np
import altair as alt
sb=pd.read_csv("sb_incorporate.csv",low_memory=False)

# %%
management = sb[sb["North American Industry Classification System, NAICS"]=="Management of companies and enterprises"]

# %%
management.head(10)
# Out:
#       Unnamed: 0 North American Industry Classification System, NAICS - code  \
# 2871        8614                                                 55
# 2872        8617                                                 55
# 2873        8620                                                 55
# 2874        8623                                                 55
# 2875        8626                                                 55
# 2876        8629                                                 55
# 2877        8632                                                 55
# 2878        8635                                                 55
# 2879        8638                                                 55
# 2880        8641                                                 55
#
#      North American Industry Classification System, NAICS  Geography - code  \
# 2871            Management of companies and enterprises                 0.0
# ...

# %%
install.packages("PerformanceAnalytics")
library(PerformanceAnalytics)
my_data <- sb[, c(11:29)]
chart.Correlation(my_data, histogram=TRUE, pch=19)
# Out:
# The downloaded binary packages are in
# 	/var/folders/b8/pn75lkrn5bn41mzb23ly_b700000gn/T//Rtmpe4Im8N/downloaded_packages
# Plot with title “”

# %%
rev1 <- lm(Net.Profit.Loss ~ Cost.of.sales..direct.expenses..... +Operating.expenses..indirect.expenses.....+Location.indicator...code, data=sb1) 
summary(rev1)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ Cost.of.sales..direct.expenses..... +
#     Operating.expenses..indirect.expenses..... + Location.indicator...code,
#     data = sb1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1132.27   -11.88    -0.21    13.83   462.20
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                583.23391    3.35586  173.80
# Cost.of.sales..direct.expenses.....         -5.48285    0.03595 -152.50
# Operating.expenses..indirect.expenses.....  -6.21042    0.03310 -187.61
# Location.indicator...code                    4.03545    1.09969    3.67
#                                            Pr(>|t|)
# (Intercept)                                 < 2e-16 ***
# Cost.of.sales..direct.expenses.....         < 2e-16 ***
# Operating.expenses..indirect.expenses.....  < 2e-16 ***
# Location.indicator...code                  0.000245 ***
# ---
# ...

# %%
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.116457 -0.003654 -0.000077  0.002505  0.116804
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                              -1.318e-02  2.599e-02
# Total.number.of.businesses                               -3.077e-08  2.145e-08
# Total.revenue                                             1.000e+00  1.697e-05
# Sales.of.goods.and.services....percent.of.total.revenue. -8.886e-05  7.990e-05
# Cost.of.sales..direct.expenses.....                       2.856e-04  3.307e-04
# Operating.expenses..indirect.expenses.....                1.102e-06  1.156e-04
# Total.expenses                                           -6.806e-01  1.187e-02
# Cost.of.sales..direct.expenses.                          -3.194e-01  1.187e-02
# ...

# %%
my_data1<-my_data[, -c(2,6,7,8)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data1) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -614.89  -11.84   -0.55   12.29  457.05
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               5.600e+02  1.789e+01
# Total.number.of.businesses                               -2.813e-05  1.628e-05
# Sales.of.goods.and.services....percent.of.total.revenue.  7.611e-03  5.839e-02
# Cost.of.sales..direct.expenses.....                      -5.253e+00  2.273e-01
# Operating.expenses..indirect.expenses.....               -5.850e+00  3.289e-02
# Total.assets                                              7.657e-01  1.110e+00
# Total.current.assets                                      1.447e-02  1.953e-03
# Total.liabilities                                        -7.921e-01  1.110e+00
# Total.current.liabilities                                 3.140e-02  1.385e-03
# ...

# %%
my_data2<-my_data1[, -c(15)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data2) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -614.87  -11.85   -0.56   12.29  457.06
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               5.617e+02  3.713e+00
# Total.number.of.businesses                               -2.820e-05  1.626e-05
# Sales.of.goods.and.services....percent.of.total.revenue.  1.164e-02  4.038e-02
# Cost.of.sales..direct.expenses.....                      -5.274e+00  3.809e-02
# Operating.expenses..indirect.expenses.....               -5.851e+00  3.245e-02
# Total.assets                                              7.650e-01  1.110e+00
# Total.current.assets                                      1.447e-02  1.953e-03
# Total.liabilities                                        -7.913e-01  1.110e+00
# Total.current.liabilities                                 3.139e-02  1.385e-03
# ...

# %%
my_data3<-my_data2[, -c(2)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data3) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -614.82  -11.86   -0.57   12.32  457.21
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.624e+02  2.678e+00  209.989
# Total.number.of.businesses                 -2.823e-05  1.626e-05   -1.737
# Cost.of.sales..direct.expenses.....        -5.269e+00  3.284e-02 -160.463
# Operating.expenses..indirect.expenses..... -5.848e+00  3.113e-02 -187.859
# Total.assets                                7.546e-01  1.109e+00    0.680
# Total.current.assets                        1.446e-02  1.952e-03    7.408
# Total.liabilities                          -7.810e-01  1.109e+00   -0.704
# Total.current.liabilities                   3.145e-02  1.371e-03   22.931
# Total.equity                               -7.517e-01  1.109e+00   -0.678
# ...

# %%
my_data4<-my_data3[, -c(5,9)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data4) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data4)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.48  -11.85   -0.69   12.27  455.52
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.642e+02  2.667e+00  211.533
# Total.number.of.businesses                 -2.971e-05  1.629e-05   -1.823
# Cost.of.sales..direct.expenses.....        -5.315e+00  3.188e-02 -166.722
# Operating.expenses..indirect.expenses..... -5.861e+00  3.111e-02 -188.410
# Total.current.assets                        2.232e-02  1.362e-03   16.382
# Total.liabilities                          -2.771e-02  5.553e-04  -49.903
# Total.current.liabilities                   3.045e-02  1.363e-03   22.346
# Debt.to.equity.ratio..times.                4.679e-01  1.318e-01    3.551
# Current.debt.to.equity....                 -3.246e-03  2.669e-03   -1.216
# ...

# %%
my_data5<-my_data4[, -c(9)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data5) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data5)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.46  -11.85   -0.73   12.28  455.32
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.642e+02  2.667e+00  211.529
# Total.number.of.businesses                 -2.979e-05  1.629e-05   -1.828
# Cost.of.sales..direct.expenses.....        -5.315e+00  3.188e-02 -166.714
# Operating.expenses..indirect.expenses..... -5.861e+00  3.111e-02 -188.400
# Total.current.assets                        2.230e-02  1.362e-03   16.372
# Total.liabilities                          -2.769e-02  5.551e-04  -49.887
# Total.current.liabilities                   3.038e-02  1.361e-03   22.312
# Debt.to.equity.ratio..times.                3.677e-01  1.028e-01    3.576
# Revenue.to.equity.ratio..times.            -3.856e-01  1.244e-01   -3.099
# ...

# %%
my_data6<-my_data5[, -c(1)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data6) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data6)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.43  -11.82   -0.73   12.35  455.49
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.639e+02  2.663e+00  211.723
# Cost.of.sales..direct.expenses.....        -5.313e+00  3.186e-02 -166.730
# Operating.expenses..indirect.expenses..... -5.860e+00  3.111e-02 -188.373
# Total.current.assets                        2.230e-02  1.362e-03   16.364
# Total.liabilities                          -2.769e-02  5.552e-04  -49.878
# Total.current.liabilities                   3.038e-02  1.362e-03   22.313
# Debt.to.equity.ratio..times.                3.660e-01  1.029e-01    3.559
# Revenue.to.equity.ratio..times.            -3.830e-01  1.244e-01   -3.078
# Net.profit.to.equity....                    2.259e-02  6.095e-03    3.707
#                                            Pr(>|t|)
# ...

# %%
my_data7<-my_data6[, -c(8)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data7) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.58  -11.96   -0.70   12.33  457.37
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.645e+02  2.657e+00  212.463
# Cost.of.sales..direct.expenses.....        -5.332e+00  3.128e-02 -170.421
# Operating.expenses..indirect.expenses..... -5.866e+00  3.107e-02 -188.820
# Total.current.assets                        2.246e-02  1.362e-03   16.485
# Total.liabilities                          -2.759e-02  5.546e-04  -49.749
# Total.current.liabilities                   3.032e-02  1.362e-03   22.254
# Debt.to.equity.ratio..times.                7.925e-02  4.356e-02    1.819
# Net.profit.to.equity....                    7.456e-03  3.602e-03    2.070
#                                            Pr(>|t|)
# (Intercept)                                  <2e-16 ***
# ...

# %%
my_data8<-my_data7[, -c(7)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data8) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data8)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.53  -11.94   -0.76   12.28  457.36
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                 5.646e+02  2.658e+00  212.430
# Cost.of.sales..direct.expenses.....        -5.330e+00  3.128e-02 -170.405
# Operating.expenses..indirect.expenses..... -5.864e+00  3.106e-02 -188.814
# Total.current.assets                        2.237e-02  1.362e-03   16.429
# Total.liabilities                          -2.758e-02  5.547e-04  -49.724
# Total.current.liabilities                   3.037e-02  1.362e-03   22.286
# Net.profit.to.equity....                    7.756e-03  3.599e-03    2.155
#                                            Pr(>|t|)
# (Intercept)                                  <2e-16 ***
# Cost.of.sales..direct.expenses.....          <2e-16 ***
# ...

# %%
my_data9<-my_data8[, -c(7)]
sb_lm <- lm(Net.Profit.Loss ~ ., data=my_data9) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = my_data9)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -629.27  -11.90   -0.72   12.28  458.88
#
# Coefficients:
#                                              Estimate Std. Error t value
# (Intercept)                                 5.651e+02  2.648e+00  213.39
# Cost.of.sales..direct.expenses.....        -5.334e+00  3.124e-02 -170.72
# Operating.expenses..indirect.expenses..... -5.868e+00  3.102e-02 -189.13
# Total.current.assets                        2.228e-02  1.362e-03   16.36
# Total.liabilities                          -2.759e-02  5.548e-04  -49.73
# Total.current.liabilities                   3.042e-02  1.363e-03   22.32
#                                            Pr(>|t|)
# (Intercept)                                  <2e-16 ***
# Cost.of.sales..direct.expenses.....          <2e-16 ***
# Operating.expenses..indirect.expenses.....   <2e-16 ***
# Total.current.assets                         <2e-16 ***
# ...

# %%
sb_urban<-sb[ which(sb$Location.indicator=='Urban'), ]
sb_rural<-sb[ which(sb$Location.indicator=='Rural'), ]
sb_urban <- sb_urban[, -c(1)]
sb_rural <- sb_rural[, -c(1)]

# %%
sb_urban1<-sb_urban[, -c(1:12,15:17,19,23:28)]
sb_rural1<-sb_rural[, -c(1:12,15:17,19,23:28)]

# %%
sb_lm_rural <- lm(Net.Profit.Loss ~ ., data=sb_rural1) 
summary(sb_lm_rural)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = sb_rural1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -347.17  -13.69   -1.74   14.03  465.25
#
# Coefficients:
#                                              Estimate Std. Error t value
# (Intercept)                                 5.415e+02  5.204e+00  104.06
# Cost.of.sales..direct.expenses.....        -5.062e+00  5.585e-02  -90.64
# Operating.expenses..indirect.expenses..... -5.686e+00  6.045e-02  -94.06
# Total.current.assets                        3.689e-02  2.462e-03   14.98
# Total.liabilities                          -3.086e-02  7.115e-04  -43.38
# Total.current.liabilities                   2.272e-02  1.927e-03   11.79
#                                            Pr(>|t|)
# (Intercept)                                  <2e-16 ***
# Cost.of.sales..direct.expenses.....          <2e-16 ***
# Operating.expenses..indirect.expenses.....   <2e-16 ***
# Total.current.assets                         <2e-16 ***
# ...

# %%
sb_lm_urban <- lm(Net.Profit.Loss ~ ., data=sb_urban1) 
summary(sb_lm_urban)
# Out:
# Call:
# lm(formula = Net.Profit.Loss ~ ., data = sb_urban1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -593.20   -9.77   -0.34   10.79  325.89
#
# Coefficients:
#                                              Estimate Std. Error  t value
# (Intercept)                                572.288573   3.115440  183.694
# Cost.of.sales..direct.expenses.....         -5.445446   0.039087 -139.315
# Operating.expenses..indirect.expenses.....  -5.892068   0.036257 -162.510
# Total.current.assets                         0.009375   0.001803    5.201
# Total.liabilities                           -0.020810   0.001009  -20.635
# Total.current.liabilities                    0.033597   0.002205   15.235
#                                            Pr(>|t|)
# (Intercept)                                 < 2e-16 ***
# Cost.of.sales..direct.expenses.....         < 2e-16 ***
# Operating.expenses..indirect.expenses.....  < 2e-16 ***
# Total.current.assets                        2.1e-07 ***
# ...

# %% [markdown]
# **Next is for the gross margin**

# %%
rev2 <- lm(Gross.margin....~  Cost.of.sales..direct.expenses..... +Location.indicator...code, data=sb1) 
summary(rev2)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ Cost.of.sales..direct.expenses..... +
#     Location.indicator...code, data = sb1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -44.542  -0.457   0.714   1.699   3.724
#
# Coefficients:
#                                      Estimate Std. Error  t value Pr(>|t|)
# (Intercept)                         96.577344   0.154042  626.953   <2e-16 ***
# Cost.of.sales..direct.expenses..... -0.970511   0.001885 -514.761   <2e-16 ***
# Location.indicator...code           -0.150721   0.085118   -1.771   0.0767 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.362 on 6269 degrees of freedom
#   (4717 observations deleted due to missingness)
# Multiple R-squared:  0.9769,	Adjusted R-squared:  0.9769
# F-statistic: 1.325e+05 on 2 and 6269 DF,  p-value: < 2.2e-16

# %%
my_data1g<-my_data[, -c(2,6,7,8)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data1g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data1g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.701  -0.437   0.060   0.743  15.538
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.307e+01  4.813e-01
# Total.number.of.businesses                               -3.335e-06  9.768e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  2.003e-01  2.425e-03
# Cost.of.sales..direct.expenses.....                      -1.064e+00  4.613e-03
# Operating.expenses..indirect.expenses.....               -2.510e-02  4.851e-03
# Net.Profit.Loss                                           7.253e-05  7.594e-04
# Total.assets                                             -3.670e-02  6.664e-02
# Total.current.assets                                      8.112e-05  1.178e-04
# Total.liabilities                                         3.683e-02  6.664e-02
# ...

# %%
my_data2g<-my_data1g[, -c(5)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data2g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data2g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.698  -0.437   0.060   0.743  15.537
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.311e+01  2.230e-01
# Total.number.of.businesses                               -3.337e-06  9.764e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  2.003e-01  2.425e-03
# Cost.of.sales..direct.expenses.....                      -1.064e+00  2.287e-03
# Operating.expenses..indirect.expenses.....               -2.552e-02  1.948e-03
# Total.assets                                             -3.665e-02  6.663e-02
# Total.current.assets                                      8.217e-05  1.173e-04
# Total.liabilities                                         3.678e-02  6.663e-02
# Total.current.liabilities                                -1.483e-04  8.318e-05
# ...

# %%
my_data3g<-my_data2g[, -c(5,7,9)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data3g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data3g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.846  -0.435   0.061   0.740  15.389
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.311e+01  2.142e-01
# Total.number.of.businesses                               -3.345e-06  9.770e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  1.985e-01  2.289e-03
# Cost.of.sales..direct.expenses.....                      -1.062e+00  2.219e-03
# Operating.expenses..indirect.expenses.....               -2.317e-02  1.825e-03
# Total.current.assets                                      1.821e-04  8.463e-05
# Total.current.liabilities                                -4.940e-05  7.712e-05
# Debt.to.equity.ratio..times.                             -2.379e-02  7.886e-03
# Current.debt.to.equity....                               -2.929e-04  1.600e-04
# ...

# %%
my_data4g<-my_data3g[, -c(6)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data4g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data4g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.815  -0.433   0.061   0.741  15.384
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.314e+01  2.098e-01
# Total.number.of.businesses                               -3.344e-06  9.769e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  1.984e-01  2.275e-03
# Cost.of.sales..direct.expenses.....                      -1.062e+00  2.218e-03
# Operating.expenses..indirect.expenses.....               -2.332e-02  1.810e-03
# Total.current.assets                                      1.421e-04  5.707e-05
# Debt.to.equity.ratio..times.                             -2.373e-02  7.885e-03
# Current.debt.to.equity....                               -2.968e-04  1.598e-04
# Revenue.to.equity.ratio..times.                           4.752e-02  7.675e-03
# ...

# %%
my_data5g<-my_data4g[, -c(7)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data5g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data5g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.792  -0.436   0.062   0.742  15.380
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.314e+01  2.099e-01
# Total.number.of.businesses                               -3.350e-06  9.771e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  1.983e-01  2.275e-03
# Cost.of.sales..direct.expenses.....                      -1.062e+00  2.219e-03
# Operating.expenses..indirect.expenses.....               -2.327e-02  1.811e-03
# Total.current.assets                                      1.372e-04  5.703e-05
# Debt.to.equity.ratio..times.                             -3.288e-02  6.156e-03
# Revenue.to.equity.ratio..times.                           4.408e-02  7.449e-03
# Net.profit.to.equity....                                 -1.851e-03  3.652e-04
# ...

# %%
my_data6g<-my_data5g[, -c(5)]
sb_lm <- lm(Gross.margin.... ~ ., data=my_data6g) 
summary(sb_lm)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = my_data6g)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.784  -0.428   0.060   0.742  15.232
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.322e+01  2.069e-01
# Total.number.of.businesses                               -3.352e-06  9.774e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  1.963e-01  2.108e-03
# Cost.of.sales..direct.expenses.....                      -1.060e+00  2.062e-03
# Operating.expenses..indirect.expenses.....               -2.160e-02  1.679e-03
# Debt.to.equity.ratio..times.                             -3.194e-02  6.146e-03
# Revenue.to.equity.ratio..times.                           4.263e-02  7.426e-03
# Net.profit.to.equity....                                 -1.803e-03  3.647e-04
#                                                           t value Pr(>|t|)
# ...

# %%
sb_urban2<-sb_urban[, -c(1:9,11,15:23,25)]
sb_rural2<-sb_rural[, -c(1:9,11,15:23,25)]

# %%
sb_lm_rural <- lm(Gross.margin....~ ., data=sb_rural2) 
summary(sb_lm_rural)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = sb_rural2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -31.955  -0.471  -0.047   0.677  17.767
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               7.977e+01  3.555e-01
# Total.number.of.businesses                               -5.768e-06  6.059e-06
# Sales.of.goods.and.services....percent.of.total.revenue.  2.109e-01  3.682e-03
# Cost.of.sales..direct.expenses.....                      -1.039e+00  4.143e-03
# Operating.expenses..indirect.expenses.....                4.038e-03  3.623e-03
# Debt.to.equity.ratio..times.                             -3.371e-02  1.188e-02
# Revenue.to.equity.ratio..times.                           3.488e-02  1.293e-02
# Net.profit.to.equity....                                 -1.669e-03  8.036e-04
#                                                           t value Pr(>|t|)
# ...

# %%
sb_lm_urban <- lm(Gross.margin....~ ., data=sb_urban2) 
summary(sb_lm_urban)
# Out:
# Call:
# lm(formula = Gross.margin.... ~ ., data = sb_urban2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -27.5791  -0.4062   0.1608   0.7545  13.9333
#
# Coefficients:
#                                                            Estimate Std. Error
# (Intercept)                                               8.593e+01  2.326e-01
# Total.number.of.businesses                               -3.764e-06  8.249e-07
# Sales.of.goods.and.services....percent.of.total.revenue.  1.771e-01  2.356e-03
# Cost.of.sales..direct.expenses.....                      -1.069e+00  2.157e-03
# Operating.expenses..indirect.expenses.....               -3.433e-02  1.653e-03
# Debt.to.equity.ratio..times.                             -3.767e-02  6.453e-03
# Revenue.to.equity.ratio..times.                           6.429e-02  8.950e-03
# Net.profit.to.equity....                                 -2.750e-03  4.226e-04
#                                                           t value Pr(>|t|)
# ...
