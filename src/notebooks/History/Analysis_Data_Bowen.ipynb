# %%
import pandas as pd
import numpy as np

# %%
import altair as alt

# %%
def tab_reader(filepathpattern,tabnum,skiprow,low_memory=False):
    tabs = []
    for i in range (tabnum):
        cur_index = i+1
        cur_filepath = filepathpattern.format(cur_index)
        try:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow, low_memory=False)
        except:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow,encoding='latin-1', low_memory=low_memory)
        tabs.append(tab)
    return tabs

# %%
# 2017 data
rcbp_2017_mb_profitMargin_Tabs = tab_reader("2017_csv_eng/2017_Medium businesses_Profit margin based_csv/_2017_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2017_mb_revenue_Tabs = tab_reader("2017_csv_eng/2017_Medium businesses_Total revenue based_csv/_2017_Eng_Medium_Revenue_Tab{}.csv",5,5)
rcbp_2017_sb_profitMargin_Tabs = tab_reader("2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",7,5)
rcbp_2017_sb_profitMargin_Tabs[0] = tab_reader("2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",1,6)[0]
rcbp_2017_sb_revenue_Tabs = tab_reader("2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",7,5)
rcbp_2017_sb_revenue_Tabs[0] = tab_reader("2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",1,6)[0]

# %%
# 2018 data
rcbp_2018_mb_profitMargin_Tabs = tab_reader("2018_csv_eng/2018_Medium businesses_Profit margin based_csv/_2018_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2018_mb_revenue_Tabs = tab_reader("2018_csv_eng/2018_Medium businesses_Total revenue based_csv/_2018_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2018_sb_profitMargin_Tabs = tab_reader("2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2018_sb_profitMargin_Tabs[0] = tab_reader("2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2018_sb_revenue_Tabs = tab_reader("2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2018_sb_revenue_Tabs[0] = tab_reader("2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
# 2019 data
rcbp_2019_mb_profitMargin_Tabs = tab_reader("2019_csv_eng/2019_Medium businesses_Profit margin_csv/_2019_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2019_mb_revenue_Tabs = tab_reader("2019_csv_eng/2019_Medium businesses_Total revenue_csv/_2019_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2019_sb_profitMargin_Tabs = tab_reader("2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2019_sb_profitMargin_Tabs[0] = tab_reader("2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2019_sb_revenue_Tabs = tab_reader("2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2019_sb_revenue_Tabs[0] = tab_reader("2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
# len(rcbp_2019_sb_revenue_Tabs)

# %%
# sb_2019_revenue_tab2 = rcbp_2019_sb_revenue_Tabs[1]

# %%
# sb_2019_cols_without_quartile = [x for x in sb_2019_revenue_tab2.columns if 'quartile' not in x.lower()]
# sb_2019_revenue_tab2=sb_2019_revenue_tab2[sb_2019_cols_without_quartile]

# %%
# sb_2019_revenue_tab2.head(10)

# %%
def selectData(tabs):
    concatTabs = []
    for tab in tabs:
        cols_without_quartile = [x for x in tab.columns if 'quartile' not in x.lower()]
        tab = tab[cols_without_quartile]
        tab = tab.loc[(tab["North American Industry Classification System, NAICS - code"].str.len() < 3) | (tab["North American Industry Classification System, NAICS - code"].str.contains('-'))]
        concatTabs.append(tab)
    return pd.concat(concatTabs)
        
# mb_2019_revenue_tab2 = rcbp_2019_mb_revenue_Tabs[1]
# mb_2019_cols_without_quartile = [x for x in mb_2019_revenue_tab2.columns if 'quartile' not in x.lower()]
# mb_2019_revenue_tab2 = mb_2019_revenue_tab2[mb_2019_cols_without_quartile]
# mb_2019_revenue_tab2 = mb_2019_revenue_tab2[mb_2019_revenue_tab2["North American Industry Classification System, NAICS - code"].str.len() < 3]

# %%
mb_2017_revenue_tab2 = rcbp_2017_mb_revenue_Tabs[1]
mb_2018_revenue_tab2 = rcbp_2018_mb_revenue_Tabs[1]
mb_2019_revenue_tab2 = rcbp_2019_mb_revenue_Tabs[1]
mb_revenue_tab2_3y = selectData([mb_2017_revenue_tab2,mb_2018_revenue_tab2,mb_2019_revenue_tab2])

# %%
# mb_2019_revenue_tab2[mb_2019_revenue_tab2.isna().any(axis=1)]

# %%
# pd.set_option('display.max_rows', None)
mb_revenue_tab2_3y
# Out:
#         ID North American Industry Classification System, NAICS - code  \
# 1      1.0                                                  0
# 2      2.0                                                  0
# 3      3.0                                                 11
# 4      4.0                                                 11
# 15    15.0                                                 21
# ..     ...                                                ...
# 200  200.0                                                 71
# 207  207.0                                                 72
# 208  208.0                                                 72
# 213  213.0                                                 81
# 214  214.0                                                 81
#
#     North American Industry Classification System, NAICS  Geography - code  \
# 1                                       All industries                 0.0
# ...

# %%
# sb_2019_revenue_tab2

# %%
# mb_revenue_tab2_3y.columns

# %%
mb_2017_revenue_tab3 = rcbp_2017_mb_revenue_Tabs[2]
mb_2018_revenue_tab3 = rcbp_2018_mb_revenue_Tabs[2]
mb_2019_revenue_tab3 = rcbp_2019_mb_revenue_Tabs[2]
mb_expenses_value_3y = selectData([mb_2017_revenue_tab3,mb_2018_revenue_tab3,mb_2019_revenue_tab3])

# %%
# mb_expenses_value_3y.columns

# %%
# mb_expenses_value_3y

# %% [markdown]
# # chart 1 - total expenses - all industry - medium businesses

# %%
# chart 1 - total expenses - all industry
chart1_df = mb_expenses_value_3y[(mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (mb_expenses_value_3y['Total expenses, percent of businesses reporting'].astype(float) >= 90) & (mb_expenses_value_3y['Total expenses, quality indicator'] < 'E')]
chart1_df = chart1_df[['Reference year','Location indicator','Total expenses']]

# %%
chart1_df
# Out:
#    Reference year Location indicator Total expenses
# 1          2017.0              Rural         8896.5
# 2          2017.0              Urban         8893.6
# 1          2018.0              Rural         8907.5
# 2          2018.0              Urban         8844.4
# 1          2019.0              Rural         8973.3
# 2          2019.0              Urban           8873

# %%
alt.Chart(chart1_df).mark_bar().encode(
    x=alt.X('Location indicator', title=''),
    y=alt.Y('Total expenses:Q', title='Total Expenses'),
    color=alt.Color('Location indicator', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %%
(float(chart1_df['Total expenses'].max()) - float(chart1_df['Total expenses'].min()))
# Out:
# 128.89999999999964

# %% [markdown]
# **The average total expenses of businesses in both rural and urban area had similar value in 2017, 2018 and 2019. The maximum differece is only about 128.9k, which is less than 2%.**

# %% [markdown]
# # chart 2 - total expenses - all industry - small businesses

# %%
sb_2017_revenue_tab2 = rcbp_2017_sb_revenue_Tabs[2]
sb_2018_revenue_tab2 = rcbp_2018_sb_revenue_Tabs[2]
sb_2019_revenue_tab2 = rcbp_2019_sb_revenue_Tabs[2]
sb_revenue_value_3y = selectData([sb_2017_revenue_tab2,sb_2018_revenue_tab2,sb_2019_revenue_tab2])

# %%
# sb_revenue_value_3y

# %%
# (sb_revenue_value_3y['Geography - code'] == 0)

# %%
# sb_revenue_value_3y[(sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Geography - code'] == 0)]

# %%
# sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & ~(sb_revenue_value_3y['Total expenses, quality indicator'].isna())]

# %%
# (mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0')

# %%
chart2_df = sb_revenue_value_3y[~(sb_revenue_value_3y['Total expenses, quality indicator'].isna()) & (sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Total expenses, quality indicator'] < 'E')]
chart2_df = chart2_df[(chart2_df['Total expenses, percent of businesses reporting'].astype(float) >= 90)]
chart2_df = chart2_df[['Reference year','Location indicator','Total expenses','Incorporation status']]
chart2_df['temp'] = chart2_df['Location indicator'] + ' - ' + chart2_df['Incorporation status']

# %%
# sb_revenue_value_3y['Total expenses, percent of businesses reporting']

# %%
# sb_revenue_value_3y.iloc[196,]

# %%
# sb_2017_revenue_tab2

# %%
alt.Chart(chart2_df).mark_bar().encode(
    x=alt.X('temp', title=''),
    y=alt.Y('Total expenses:Q', title='Total Expenses'),
    color=alt.Color('Incorporation status', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=200, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **In recorded 3 years (2017,2018,2019), whatever incorporation status are, average total expenses of businesses in rural area always larger than urban area, while the differences are more obvious on incorporated businesses. Furthermore, these differences grown slightly in these 3 years.**

# %% [markdown]
# # chart 3 - Rural direct/indirect cost expenses - all industry - medium businesses

# %%
chart3_df = mb_expenses_value_3y[(mb_expenses_value_3y['Location indicator'] == 'Rural') & (mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (mb_expenses_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (mb_expenses_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart3_df = chart3_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart3_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 1          2017.0              Rural                          5418.4
# 1          2018.0              Rural                          5412.4
# 1          2019.0              Rural                          5402.4
#
#   Operating expenses (indirect expenses)
# 1                                 3478.1
# 1                                 3495.1
# 1                                 3570.9

# %%
chart3_df = chart3_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart3_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Rural         Cost of sales (direct expenses)
# 1          2018.0              Rural         Cost of sales (direct expenses)
# 2          2019.0              Rural         Cost of sales (direct expenses)
# 3          2017.0              Rural  Operating expenses (indirect expenses)
# 4          2018.0              Rural  Operating expenses (indirect expenses)
# 5          2019.0              Rural  Operating expenses (indirect expenses)
#
#     value
# 0  5418.4
# 1  5412.4
# 2  5402.4
# 3  3478.1
# 4  3495.1
# 5  3570.9

# %%
alt.Chart(chart3_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For rural businesses, in recorded 3 years, the average direct expenses are larger than the average indirect expenses, while the differences are about 2000K**

# %% [markdown]
# # chart 4 - Urban direct/indirect cost expenses - all industry - medium businesses

# %%
chart4_df = mb_expenses_value_3y[(mb_expenses_value_3y['Location indicator'] == 'Urban') & (mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (mb_expenses_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (mb_expenses_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart4_df = chart4_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart4_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 2          2017.0              Urban                          5635.2
# 2          2018.0              Urban                          5578.7
# 2          2019.0              Urban                          5537.5
#
#   Operating expenses (indirect expenses)
# 2                                 3258.4
# 2                                 3265.7
# 2                                 3335.5

# %%
chart4_df = chart4_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart4_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Urban         Cost of sales (direct expenses)
# 1          2018.0              Urban         Cost of sales (direct expenses)
# 2          2019.0              Urban         Cost of sales (direct expenses)
# 3          2017.0              Urban  Operating expenses (indirect expenses)
# 4          2018.0              Urban  Operating expenses (indirect expenses)
# 5          2019.0              Urban  Operating expenses (indirect expenses)
#
#     value
# 0  5635.2
# 1  5578.7
# 2  5537.5
# 3  3258.4
# 4  3265.7
# 5  3335.5

# %%
alt.Chart(chart4_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For urban businesses, in recorded 3 years, the average direct expenses are also larger than the average indirect expenses, while the differences are more than 2000K**

# %% [markdown]
# # chart 5 - Rural direct/indirect cost expenses - all industry - small businesses - all businesses

# %%
chart5_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['Location indicator'] == 'Rural') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart5_df = chart5_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart5_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 3          2017.0              Rural                           144.1
# 3          2018.0              Rural                           144.2
# 3          2019.0              Rural                           143.9
#
#   Operating expenses (indirect expenses)
# 3                                  264.6
# 3                                  268.3
# 3                                  273.3

# %%
chart5_df = chart5_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart5_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Rural         Cost of sales (direct expenses)
# 1          2018.0              Rural         Cost of sales (direct expenses)
# 2          2019.0              Rural         Cost of sales (direct expenses)
# 3          2017.0              Rural  Operating expenses (indirect expenses)
# 4          2018.0              Rural  Operating expenses (indirect expenses)
# 5          2019.0              Rural  Operating expenses (indirect expenses)
#
#    value
# 0  144.1
# 1  144.2
# 2  143.9
# 3  264.6
# 4  268.3
# 5  273.3

# %%
alt.Chart(chart5_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, it becomes different. In recorded 3 years, the average direct expenses are smaller than the average indirect expenses, while the differences are more than 200K**

# %% [markdown]
# # chart 6 - Rural direct/indirect cost expenses - all industry - small businesses - incorporated businesses

# %%
chart6_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'Incorporated') & (sb_revenue_value_3y['Location indicator'] == 'Rural') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart6_df = chart6_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart6_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 2          2017.0              Rural                           205.8
# 2          2018.0              Rural                           205.6
# 2          2019.0              Rural                           206.6
#
#   Operating expenses (indirect expenses)
# 2                                  386.6
# 2                                  391.1
# 2                                  400.2

# %%
chart6_df = chart6_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart6_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Rural         Cost of sales (direct expenses)
# 1          2018.0              Rural         Cost of sales (direct expenses)
# 2          2019.0              Rural         Cost of sales (direct expenses)
# 3          2017.0              Rural  Operating expenses (indirect expenses)
# 4          2018.0              Rural  Operating expenses (indirect expenses)
# 5          2019.0              Rural  Operating expenses (indirect expenses)
#
#    value
# 0  205.8
# 1  205.6
# 2  206.6
# 3  386.6
# 4  391.1
# 5  400.2

# %%
alt.Chart(chart6_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, similar trend for incorporated businesses**

# %% [markdown]
# # chart 7 - Rural direct/indirect cost expenses - all industry - small businesses - Unincorporated businesses

# %%
chart7_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'Unincorporated') & (sb_revenue_value_3y['Location indicator'] == 'Rural') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart7_df = chart7_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart7_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 1          2017.0              Rural                            37.9
# 1          2018.0              Rural                            37.2
# 1          2019.0              Rural                            35.4
#
#   Operating expenses (indirect expenses)
# 1                                   54.1
# 1                                   54.3
# 1                                   53.8

# %%
chart7_df = chart7_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart7_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Rural         Cost of sales (direct expenses)
# 1          2018.0              Rural         Cost of sales (direct expenses)
# 2          2019.0              Rural         Cost of sales (direct expenses)
# 3          2017.0              Rural  Operating expenses (indirect expenses)
# 4          2018.0              Rural  Operating expenses (indirect expenses)
# 5          2019.0              Rural  Operating expenses (indirect expenses)
#
#   value
# 0  37.9
# 1  37.2
# 2  35.4
# 3  54.1
# 4  54.3
# 5  53.8

# %%
alt.Chart(chart7_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, similar trend for incorporated businesses**

# %% [markdown]
# # chart 8 - Urban direct/indirect cost expenses - all industry - small businesses - all businesses

# %%
chart8_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['Location indicator'] == 'Urban') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart8_df = chart8_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart8_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 6          2017.0              Urban                           139.6
# 6          2018.0              Urban                           137.4
# 6          2019.0              Urban                           134.7
#
#   Operating expenses (indirect expenses)
# 6                                  200.5
# 6                                  202.7
# 6                                  203.8

# %%
chart8_df = chart8_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart8_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Urban         Cost of sales (direct expenses)
# 1          2018.0              Urban         Cost of sales (direct expenses)
# 2          2019.0              Urban         Cost of sales (direct expenses)
# 3          2017.0              Urban  Operating expenses (indirect expenses)
# 4          2018.0              Urban  Operating expenses (indirect expenses)
# 5          2019.0              Urban  Operating expenses (indirect expenses)
#
#    value
# 0  139.6
# 1  137.4
# 2  134.7
# 3  200.5
# 4  202.7
# 5  203.8

# %%
alt.Chart(chart8_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small urban businesses, it becomes different. In recorded 3 years, the average direct expenses are smaller than the average indirect expenses, while the differences are more than 60K**

# %% [markdown]
# # chart 9 - Urban direct/indirect cost expenses - all industry - small businesses - incorporated businesses

# %%
chart9_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'Incorporated') & (sb_revenue_value_3y['Location indicator'] == 'Urban') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart9_df = chart9_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart9_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 5          2017.0              Urban                           210.4
# 5          2018.0              Urban                           206.4
# 5          2019.0              Urban                           205.9
#
#   Operating expenses (indirect expenses)
# 5                                  290.3
# 5                                  292.8
# 5                                  299.1

# %%
chart9_df = chart9_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart9_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Urban         Cost of sales (direct expenses)
# 1          2018.0              Urban         Cost of sales (direct expenses)
# 2          2019.0              Urban         Cost of sales (direct expenses)
# 3          2017.0              Urban  Operating expenses (indirect expenses)
# 4          2018.0              Urban  Operating expenses (indirect expenses)
# 5          2019.0              Urban  Operating expenses (indirect expenses)
#
#    value
# 0  210.4
# 1  206.4
# 2  205.9
# 3  290.3
# 4  292.8
# 5  299.1

# %%
alt.Chart(chart9_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small urban businesses, similar trend for incorporated businesses**

# %% [markdown]
# # chart 10 - Urban direct/indirect cost expenses - all industry - small businesses - Unincorporated businesses

# %%
chart10_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'Unincorporated') & (sb_revenue_value_3y['Location indicator'] == 'Urban') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart10_df = chart10_df[['Reference year','Location indicator','Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]

# %%
chart10_df
# Out:
#    Reference year Location indicator Cost of sales (direct expenses)  \
# 4          2017.0              Urban                            20.6
# 4          2018.0              Urban                            19.7
# 4          2019.0              Urban                            18.2
#
#   Operating expenses (indirect expenses)
# 4                                   49.7
# 4                                   49.1
# 4                                   47.8

# %%
chart10_df = chart10_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart10_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Urban         Cost of sales (direct expenses)
# 1          2018.0              Urban         Cost of sales (direct expenses)
# 2          2019.0              Urban         Cost of sales (direct expenses)
# 3          2017.0              Urban  Operating expenses (indirect expenses)
# 4          2018.0              Urban  Operating expenses (indirect expenses)
# 5          2019.0              Urban  Operating expenses (indirect expenses)
#
#   value
# 0  20.6
# 1  19.7
# 2  18.2
# 3  49.7
# 4  49.1
# 5  47.8

# %%
alt.Chart(chart10_df).mark_bar().encode(
    x=alt.X('type', title=''),
    y=alt.Y('value:Q', title='Expenses Value'),
    color=alt.Color('type', legend=None),
    column=alt.Column('Reference year', title='')
).properties(width=100, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small urban businesses, similar trend for incorporated businesses**

# %%
sb_revenue_value_3y.columns
# Out:
# Index(['ID', 'North American Industry Classification System, NAICS - code',
#        'North American Industry Classification System, NAICS',
#        'Geography - code', 'Geography', 'Location indicator - code',
#        'Location indicator', 'Incorporation status - code',
#        'Incorporation status', 'Reference year',
#        'Cost of sales (direct expenses)',
#        'Cost of sales (direct expenses), quality indicator',
#        'Cost of sales (direct expenses), percent of businesses reporting',
#        'Wages and benefits', 'Wages and benefits, quality indicator',
#        'Wages and benefits, percent of businesses reporting',
#        'Purchases, materials and sub-contracts',
#        'Purchases, materials and sub-contracts, quality indicator',
#        'Purchases, materials and sub-contracts, percent of businesses reporting',
#        'Opening inventory', 'Opening inventory, quality indicator',
#        'Opening inventory, percent of businesses reporting',
# ...

# %% [markdown]
# # chart 11 - Rural different type cost expenses - all industry - small businesses - all businesses

# %%
chart11_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['Location indicator'] == 'Rural') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart11_df = chart11_df[['Reference year','Location indicator',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
                           'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]

# %%
chart11_df
# Out:
#    Reference year Location indicator Wages and benefits  \
# 3          2017.0              Rural               21.6
# 3          2018.0              Rural               21.8
# 3          2019.0              Rural               22.7
#
#   Purchases, materials and sub-contracts Opening inventory Closing inventory  \
# 3                                  123.1              26.3              26.9
# 3                                  123.3              25.4              26.3
# 3                                  121.8              25.6              26.2
#
#   Labour and commissions Amortization and depletion Repairs and maintenance  \
# 3                   67.4                       26.3                    16.5
# 3                   67.9                       26.4                    16.6
# 3                   68.7                       27.4                    16.9
#
#   Utilities and telephone/telecommunication  Rent Interest and bank charges  \
# ...

# %%
chart11_df = chart11_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart11_df['value'] = chart11_df['value'].astype(float)

# %%
alt.Chart(chart11_df).mark_bar().encode(
    x=alt.X('value:Q', title='Expenses Value'),
    y=alt.Y('type', title='',sort='x'),
    color=alt.Color('type', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, Purchases, materials and sub-contracts, Other indirect expenses, Labour and commissions are top 3 cost type.**

# %% [markdown]
# # chart 12 - Urban different type cost expenses - all industry - small businesses - all businesses

# %%
chart12_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['Location indicator'] == 'Urban') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (sb_revenue_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (sb_revenue_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart12_df = chart12_df[['Reference year','Location indicator',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
                           'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]

# %%
chart12_df
# Out:
#    Reference year Location indicator Wages and benefits  \
# 6          2017.0              Urban               22.8
# 6          2018.0              Urban               22.6
# 6          2019.0              Urban               22.5
#
#   Purchases, materials and sub-contracts Opening inventory Closing inventory  \
# 6                                  118.4              24.8              26.4
# 6                                    117              24.6              26.8
# 6                                  113.3              25.4              26.5
#
#   Labour and commissions Amortization and depletion Repairs and maintenance  \
# 6                   73.7                       12.5                     8.9
# 6                   74.3                       12.7                     9.1
# 6                   74.7                       13.1                     9.1
#
#   Utilities and telephone/telecommunication  Rent Interest and bank charges  \
# ...

# %%
chart12_df = chart12_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart12_df['value'] = chart12_df['value'].astype(float)

# %%
alt.Chart(chart12_df).mark_bar().encode(
    x=alt.X('value:Q', title='Expenses Value'),
    y=alt.Y('type', title='',sort='x'),
    color=alt.Color('type', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, Purchases, materials and sub-contracts, Labour and commissions, Other indirect expenses are top 3 cost type.**

# %% [markdown]
# # chart 13 - Rural different type cost expenses - all industry - medium businesses - all businesses

# %%
chart13_df = mb_expenses_value_3y[(mb_expenses_value_3y['Location indicator'] == 'Rural') & (mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (mb_expenses_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (mb_expenses_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart13_df = chart13_df[['Reference year','Location indicator',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
                           'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]

# %%
chart13_df
# Out:
#    Reference year Location indicator Wages and benefits  \
# 1          2017.0              Rural              598.2
# 1          2018.0              Rural              616.4
# 1          2019.0              Rural              642.3
#
#   Purchases, materials and sub-contracts Opening inventory Closing inventory  \
# 1                                 4889.5             911.2             980.4
# 1                                 4875.9             899.3             979.2
# 1                                 4801.2             941.6             982.6
#
#   Labour and commissions Amortization and depletion Repairs and maintenance  \
# 1                    983                      266.6                   183.1
# 1                  976.7                      261.5                   185.4
# 1                  998.4                      278.3                     187
#
#   Utilities and telephone/telecommunication   Rent Interest and bank charges  \
# ...

# %%
chart13_df = chart13_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart13_df['value'] = chart13_df['value'].astype(float)

# %%
alt.Chart(chart13_df).mark_bar().encode(
    x=alt.X('value:Q', title='Expenses Value'),
    y=alt.Y('type', title='',sort='x'),
    color=alt.Color('type', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For medium rural businesses, Purchases, materials and sub-contracts, Other indirect expenses, 'Opening inventory',
#                            'Closing inventory', 'Labour and commissions' are top 5 cost type.**

# %% [markdown]
# open inventory < closing inventory, 生产比卖的的多, bad thing
# inventory 越低越好

# %% [markdown]
# # chart 14 - Urban different type cost expenses - all industry - medium businesses - all businesses

# %%
chart14_df = mb_expenses_value_3y[(mb_expenses_value_3y['Location indicator'] == 'Urban') & (mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] == '0') & (mb_expenses_value_3y['Cost of sales (direct expenses), quality indicator'] < 'D') & (mb_expenses_value_3y['Operating expenses (indirect expenses)'] < 'D')]
chart14_df = chart14_df[['Reference year','Location indicator',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
                           'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]

# %%
chart14_df
# Out:
#    Reference year Location indicator Wages and benefits  \
# 2          2017.0              Urban              805.5
# 2          2018.0              Urban              821.2
# 2          2019.0              Urban              827.9
#
#   Purchases, materials and sub-contracts Opening inventory Closing inventory  \
# 2                                 4862.4             886.3             918.9
# 2                                 4825.3               853             920.7
# 2                                 4731.8             872.2             894.4
#
#   Labour and commissions Amortization and depletion Repairs and maintenance  \
# 2                 1303.9                      214.4                    93.3
# 2                 1316.3                      208.4                    96.4
# 2                 1340.4                      220.6                    98.1
#
#   Utilities and telephone/telecommunication   Rent Interest and bank charges  \
# ...

# %%
chart14_df = chart14_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart14_df['value'] = chart14_df['value'].astype(float)

# %%
alt.Chart(chart14_df).mark_bar().encode(
    x=alt.X('value:Q', title='Expenses Value'),
    y=alt.Y('type', title='',sort='x'),
    color=alt.Color('type', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For medium urban businesses, Purchases, materials and sub-contracts, Other indirect expenses, Opening inventory,
#                            Closing inventory, Labour and commissions are top 5 cost type.**

# %% [markdown]
# # chart 15 - total expenses - diff industry - rural - medium businesses

# %%
# chart 15 - total expenses - all industry
chart15_df = mb_expenses_value_3y[(mb_expenses_value_3y['North American Industry Classification System, NAICS - code'] != '0') & (mb_expenses_value_3y['Total expenses, percent of businesses reporting'].astype(float) >= 90) & (mb_expenses_value_3y['Total expenses, quality indicator'] < 'E')]
chart15_df = chart15_df[['North American Industry Classification System, NAICS','Reference year','Location indicator','Total expenses']]

# %%
chart15_df = chart15_df[chart15_df['Location indicator'] == 'Rural']

# %%
chart15_df.loc[:,'Total expenses'] = chart15_df.loc[:,'Total expenses'].astype(float)

# %%
chart15_df
# Out:
#     North American Industry Classification System, NAICS  Reference year  \
# 3           Agriculture, forestry, fishing and hunting            2017.0
# 15       Mining, quarrying, and oil and gas extraction            2017.0
# 23                                           Utilities            2017.0
# 27                                        Construction            2017.0
# 35                                       Manufacturing            2017.0
# 79                                     Wholesale trade            2017.0
# 99                                        Retail trade            2017.0
# 125                     Transportation and warehousing            2017.0
# 149                Information and cultural industries            2017.0
# 163                 Real estate and rental and leasing            2017.0
# 171    Professional, scientific and technical services            2017.0
# 175            Management of companies and enterprises            2017.0
# ...

# %%
alt.Chart(chart15_df).mark_bar().encode(
    x=alt.X('Total expenses:Q', title='Total Expenses'),
    y=alt.Y('North American Industry Classification System, NAICS', title='',sort='x'),
    color=alt.Color('North American Industry Classification System, NAICS', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For medium rural businesses, Agriculture, forestry, fishing and hunting, Wholesale trade, Retail trade are top 3 industries that have most average total expenses.**

# %% [markdown]
# # chart 16 - Rural total expenses - diff industry - small businesses - all businesses - Canada

# %%
chart16_df = sb_revenue_value_3y[(sb_revenue_value_3y['Geography - code'] == 0) & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['Location indicator'] == 'Rural') & (sb_revenue_value_3y['North American Industry Classification System, NAICS - code'] != '0') & (sb_revenue_value_3y['Total expenses, quality indicator'] < 'E')]
chart16_df = chart16_df[['North American Industry Classification System, NAICS','Reference year','Location indicator','Total expenses']]

# %%
chart16_df.loc[:,'Total expenses'] = chart16_df.loc[:,'Total expenses'].astype(float)

# %%
chart5_df = chart5_df.melt(id_vars=['Reference year', 'Location indicator'], var_name='type',
             value_name='value')

# %%
chart5_df
# Out:
#    Reference year Location indicator                                    type  \
# 0          2017.0              Rural         Cost of sales (direct expenses)
# 1          2018.0              Rural         Cost of sales (direct expenses)
# 2          2019.0              Rural         Cost of sales (direct expenses)
# 3          2017.0              Rural  Operating expenses (indirect expenses)
# 4          2018.0              Rural  Operating expenses (indirect expenses)
# 5          2019.0              Rural  Operating expenses (indirect expenses)
#
#    value
# 0  144.1
# 1  144.2
# 2  143.9
# 3  264.6
# 4  268.3
# 5  273.3

# %%
alt.Chart(chart16_df).mark_bar().encode(
    x=alt.X('Total expenses:Q', title='Total Expenses'),
    y=alt.Y('North American Industry Classification System, NAICS', title='',sort='x'),
    color=alt.Color('North American Industry Classification System, NAICS', legend=None),
    row=alt.Row('Reference year', title='')
).properties(width=400, height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# **For small rural businesses, Agriculture, forestry, fishing and hunting, Wholesale trade, Retail trade are top 3 industries that have most average total expenses. But Retail trade becomes the industry that has most total expenses**
