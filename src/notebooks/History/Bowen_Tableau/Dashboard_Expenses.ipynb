# %%
import pandas as pd
import numpy as np
def tab_reader(filepathpattern,tabnum,skiprow,low_memory=False):
    tabs = []
    for i in range (tabnum):
        cur_index = i+1
        cur_filepath = filepathpattern.format(cur_index)
        try:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow, low_memory=False)
        except:
            tab = pd.read_csv(cur_filepath, skiprows=skiprow,encoding='latin-1', low_memory=low_memory)
        tabs.append(tab)
    return tabs

# %%
# 2017 data
rcbp_2017_mb_profitMargin_Tabs = tab_reader("2017_csv_eng/2017_Medium businesses_Profit margin based_csv/_2017_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2017_mb_revenue_Tabs = tab_reader("2017_csv_eng/2017_Medium businesses_Total revenue based_csv/_2017_Eng_Medium_Revenue_Tab{}.csv",5,5)
rcbp_2017_sb_profitMargin_Tabs = tab_reader("2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",7,5)
rcbp_2017_sb_profitMargin_Tabs[0] = tab_reader("2017_csv_eng/2017_Small businesses_Profit margin based_csv/_2017_Small businesses_Profit margin based_Tab{}.csv",1,6)[0]
rcbp_2017_sb_revenue_Tabs = tab_reader("2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",7,5)
rcbp_2017_sb_revenue_Tabs[0] = tab_reader("2017_csv_eng/2017_Small businesses_Total revenue based_csv/_2017_Small businesses_Total revenue based_Tab{}.csv",1,6)[0]

# %%
# 2018 data
rcbp_2018_mb_profitMargin_Tabs = tab_reader("2018_csv_eng/2018_Medium businesses_Profit margin based_csv/_2018_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2018_mb_revenue_Tabs = tab_reader("2018_csv_eng/2018_Medium businesses_Total revenue based_csv/_2018_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2018_sb_profitMargin_Tabs = tab_reader("2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2018_sb_profitMargin_Tabs[0] = tab_reader("2018_csv_eng/2018_Small businesses_Profit margin based_csv/_2018_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2018_sb_revenue_Tabs = tab_reader("2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2018_sb_revenue_Tabs[0] = tab_reader("2018_csv_eng/2018_Small businesses_Total revenue based_csv/_2018_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
# 2019 data
rcbp_2019_mb_profitMargin_Tabs = tab_reader("2019_csv_eng/2019_Medium businesses_Profit margin_csv/_2019_Medium businesses_Profit margin_Tab{}.csv",5,5)
rcbp_2019_mb_revenue_Tabs = tab_reader("2019_csv_eng/2019_Medium businesses_Total revenue_csv/_2019_Medium businesses_Total revenue_Tab{}.csv",5,5)
rcbp_2019_sb_profitMargin_Tabs = tab_reader("2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",7,5)
rcbp_2019_sb_profitMargin_Tabs[0] = tab_reader("2019_csv_eng/2019_Small businesses_Profit margin_csv/_2019_Small businesses_Profit margin_Tab{}.csv",1,6)[0]
rcbp_2019_sb_revenue_Tabs = tab_reader("2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",7,5)
rcbp_2019_sb_revenue_Tabs[0] = tab_reader("2019_csv_eng/2019_Small businesses_Total revenue_csv/_2019_Small businesses_Total revenue_Tab{}.csv",1,6)[0]

# %%
def selectData(tabs):
    concatTabs = []
    for tab in tabs:
        cols_without_quartile = [x for x in tab.columns if 'quartile' not in x.lower()]
        tab = tab[cols_without_quartile]
        tab = tab.loc[(tab["North American Industry Classification System, NAICS - code"].str.len() < 3) | (tab["North American Industry Classification System, NAICS - code"].str.contains('-'))]
        concatTabs.append(tab)
    return pd.concat(concatTabs)

# %%
mb_2017_revenue_tab2 = rcbp_2017_mb_revenue_Tabs[1]
mb_2018_revenue_tab2 = rcbp_2018_mb_revenue_Tabs[1]
mb_2019_revenue_tab2 = rcbp_2019_mb_revenue_Tabs[1]
mb_revenue_persent_3y = selectData([mb_2017_revenue_tab2,mb_2018_revenue_tab2,mb_2019_revenue_tab2])

# %%
mb_2017_revenue_tab3 = rcbp_2017_mb_revenue_Tabs[2]
mb_2018_revenue_tab3 = rcbp_2018_mb_revenue_Tabs[2]
mb_2019_revenue_tab3 = rcbp_2019_mb_revenue_Tabs[2]
mb_expenses_value_3y = selectData([mb_2017_revenue_tab3,mb_2018_revenue_tab3,mb_2019_revenue_tab3])

# %%
sb_2017_revenue_tab2 = rcbp_2017_sb_revenue_Tabs[1]
sb_2018_revenue_tab2 = rcbp_2018_sb_revenue_Tabs[1]
sb_2019_revenue_tab2 = rcbp_2019_sb_revenue_Tabs[1]
sb_revenue_persent_3y = selectData([sb_2017_revenue_tab2,sb_2018_revenue_tab2,sb_2019_revenue_tab2])

# %%
sb_2017_revenue_tab3 = rcbp_2017_sb_revenue_Tabs[2]
sb_2018_revenue_tab3 = rcbp_2018_sb_revenue_Tabs[2]
sb_2019_revenue_tab3 = rcbp_2019_sb_revenue_Tabs[2]
sb_revenue_value_3y = selectData([sb_2017_revenue_tab3,sb_2018_revenue_tab3,sb_2019_revenue_tab3])

# %%
# mb_revenue_persent_3y.columns
# mb_revenue_persent_3y = mb_revenue_persent_3y.iloc[1:,:]
# mb_revenue_persent_3y = mb_revenue_persent_3y.drop(columns=['Net Profit/Loss (%)', 'Net Profit/Loss (%), quality indicator'])

# %%
# mb_revenue_persent_3y.to_csv("Medium_Business_Expenses_Persentage.csv", index=False)

# %%
# sb_revenue_persent_3y.columns
# sb_revenue_persent_3y = sb_revenue_persent_3y.iloc[1:,:]
# sb_revenue_persent_3y = sb_revenue_persent_3y.drop(columns=['Net Profit/Loss (%)', 'Net Profit/Loss (%), quality indicator'])

# %%
# sb_revenue_persent_3y.to_csv("Small_Business_Expenses_Persentage.csv", index=False)

# %%
# mb_expenses_value_3y.columns
# mb_expenses_value_3y = mb_expenses_value_3y.iloc[1:,:]
mb_expenses_value_3y = mb_expenses_value_3y.drop(columns=['Net Profit/Loss', 'Net Profit/Loss, quality indicator'])

# %%
# mb_expenses_value_3y.to_csv("Medium_Business_Expenses.csv", index=False)

# %%
# sb_revenue_value_3y.columns
# sb_revenue_value_3y = sb_revenue_value_3y.iloc[1:,:]
# sb_revenue_value_3y = sb_revenue_value_3y.drop(columns=['Net Profit/Loss', 'Net Profit/Loss, quality indicator'])

# %%
# sb_revenue_value_3y.to_csv("Small_Business_Expenses.csv", index=False)

# %%
rm_geo = list(['Altantic', 'Prairies', 'Territories'])
sb_revenue_value_3y = sb_revenue_value_3y.loc[~sb_revenue_value_3y.Geography.isin(rm_geo)]
sb_revenue_value_3y.loc[sb_revenue_value_3y.Geography=='Nordwest Territories','Geography'] = 'Northwest Territories'

# %%
mb_pieChart2_df = mb_expenses_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year',
                          'Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]
mb_pieChart2_df = mb_pieChart2_df.melt(id_vars=['North American Industry Classification System, NAICS',
                          'Geography', 'Location indicator', 'Incorporation status', 'Reference year'], var_name='type',value_name='value')
mb_pieChart2_df.to_excel("Medium_Business_Expenses_PieChart2.xlsx")

# %%
sb_pieChart2_df = sb_revenue_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year',
                          'Cost of sales (direct expenses)','Operating expenses (indirect expenses)']]
sb_pieChart2_df = sb_pieChart2_df.melt(id_vars=['North American Industry Classification System, NAICS',
                          'Geography', 'Location indicator', 'Incorporation status', 'Reference year'], var_name='type',value_name='value')
sb_pieChart2_df.to_excel("Small_Business_Expenses_PieChart2.xlsx")

# %%
mb_expenses_value_3y['Inventory'] = mb_expenses_value_3y['Opening inventory'].astype(float) - mb_expenses_value_3y['Closing inventory'].astype(float)

# %%
mb_expenses_value_3y[mb_expenses_value_3y['Inventory'] < 0]
# Out:
#         ID North American Industry Classification System, NAICS - code  \
# 1      1.0                                                  0
# 2      2.0                                                  0
# 3      3.0                                                 11
# 4      4.0                                                 11
# 15    15.0                                                 21
# ..     ...                                                ...
# 175  175.0                                                 55
# 179  179.0                                                 56
# 199  199.0                                                 71
# 200  200.0                                                 71
# 214  214.0                                                 81
#
#     North American Industry Classification System, NAICS  Geography - code  \
# 1                                       All industries                 0.0
# ...

# %%
# mb_pieChart_df = mb_expenses_value_3y[['North American Industry Classification System, NAICS - code',
#                           'North American Industry Classification System, NAICS',
#                           'Geography - code', 'Geography', 'Location indicator - code',
#                           'Location indicator', 'Incorporation status - code',
#                           'Incorporation status', 'Reference year',
#                         'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
#                            'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
#                            'Repairs and maintenance', 'Utilities and telephone/telecommunication',
#                          'Rent', 'Interest and bank charges', 'Professional and business fees',
#                          'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
#                          'Other indirect expenses']]

# mb_pieChart_df = mb_expenses_value_3y[['North American Industry Classification System, NAICS','Geography',
#                           'Location indicator', 'Incorporation status', 'Reference year',
#                         'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
#                            'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
#                            'Repairs and maintenance', 'Utilities and telephone/telecommunication',
#                          'Rent', 'Interest and bank charges', 'Professional and business fees',
#                          'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
#                          'Other indirect expenses']]

mb_pieChart_df = mb_expenses_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Inventory', 
                           'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]

# %%
# pieChart_df = pieChart_df.melt(id_vars=['North American Industry Classification System, NAICS - code',
#                           'North American Industry Classification System, NAICS',
#                           'Geography - code', 'Geography', 'Location indicator - code',
#                           'Location indicator', 'Incorporation status - code',
#                           'Incorporation status', 'Reference year'], var_name='type',
#              value_name='value')
# mb_pieChart_df = mb_pieChart_df.iloc[1:,:]

# %%
# mb_pieChart_df = mb_pieChart_df.melt(id_vars=['North American Industry Classification System, NAICS - code',
#                           'North American Industry Classification System, NAICS',
#                           'Geography - code', 'Geography', 'Location indicator - code',
#                           'Location indicator', 'Incorporation status - code',
#                           'Incorporation status', 'Reference year'], var_name='type',
#              value_name='value')

mb_pieChart_df = mb_pieChart_df.melt(id_vars=['North American Industry Classification System, NAICS',
                          'Geography', 'Location indicator', 'Incorporation status', 'Reference year'], var_name='type',value_name='value')

# %%
mb_pieChart_df
# Out:
#      North American Industry Classification System, NAICS Geography  \
# 0                                        All industries      Canada
# 1                                        All industries      Canada
# 2            Agriculture, forestry, fishing and hunting      Canada
# 3            Agriculture, forestry, fishing and hunting      Canada
# 4         Mining, quarrying, and oil and gas extraction      Canada
# ...                                                 ...         ...
# 1591                 Arts, entertainment and recreation      Canada
# 1592                    Accommodation and food services      Canada
# 1593                    Accommodation and food services      Canada
# 1594      Other services (except public administration)      Canada
# 1595      Other services (except public administration)      Canada
#
#      Location indicator Incorporation status  Reference year  \
# 0                 Rural         Incorporated          2017.0
# ...

# %%
mb_pieChart_df.to_csv("Medium_Business_Expenses_PieChart.csv", index=False)

# %%
mb_pieChart_df.to_excel("Medium_Business_Expenses_PieChart.xlsx")

# %%
len(sb_revenue_value_3y)
# Out:
# 4617

# %%
temp2 = mb_pieChart_df[(mb_pieChart_df['Reference year'] == 2017) & (mb_pieChart_df['Location indicator'] == 'Urban') & (mb_pieChart_df['North American Industry Classification System, NAICS'] == 'All industries')]

# %%
temp2['value'].astype(float).sum()
# Out:
# 8893.9

# %%
sb_revenue_value_3y[(sb_revenue_value_3y['Opening inventory'] == 'X') | (sb_revenue_value_3y['Closing inventory'] == 'X')]
# Out:
#             ID North American Industry Classification System, NAICS - code  \
# 184      184.0                                                 11
# 185      185.0                                                 11
# 186      186.0                                                 11
# 187      187.0                                                 11
# 188      188.0                                                 11
# ...        ...                                                ...
# 10296  10296.0                                                 72
# 10579  10579.0                                                 81
# 10580  10580.0                                                 81
# 10591  10591.0                                                 81
# 10592  10592.0                                                 81
#
#       North American Industry Classification System, NAICS  Geography - code  \
# 184           Agriculture, forestry, fishing and hunting                60.0
# ...

# %%
try:
    sb_revenue_value_3y['Inventory'] = sb_revenue_value_3y['Opening inventory'].astype(float) - sb_revenue_value_3y['Closing inventory'].astype(float)
except:
    sb_revenue_value_3y['Inventory'] = sb_revenue_value_3y['Opening inventory']

# %%
# sb_pieChart_df = sb_revenue_value_3y[['North American Industry Classification System, NAICS','Geography',
#                           'Location indicator', 'Incorporation status', 'Reference year',
#                         'Wages and benefits', 'Purchases, materials and sub-contracts', 'Opening inventory', 
#                            'Closing inventory', 'Labour and commissions', 'Amortization and depletion',
#                            'Repairs and maintenance', 'Utilities and telephone/telecommunication',
#                          'Rent', 'Interest and bank charges', 'Professional and business fees',
#                          'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
#                          'Other indirect expenses']]
sb_pieChart_df = sb_revenue_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year',
                        'Wages and benefits', 'Purchases, materials and sub-contracts', 'Inventory', 
                           'Labour and commissions', 'Amortization and depletion',
                           'Repairs and maintenance', 'Utilities and telephone/telecommunication',
                         'Rent', 'Interest and bank charges', 'Professional and business fees',
                         'Advertising and promotion', 'Delivery, shipping and warehouse', 'Insurance', 
                         'Other indirect expenses']]
sb_pieChart_df = sb_pieChart_df.melt(id_vars=['North American Industry Classification System, NAICS',
                          'Geography', 'Location indicator', 'Incorporation status', 'Reference year'], var_name='type',value_name='value')

# %%
sb_pieChart_df.to_excel("Small_Business_Expenses_PieChart.xlsx")

# %%
# sb_revenue_value_3y[sb_revenue_value_3y['Inventory'] < 0]

# %%
temp = sb_pieChart_df[(sb_pieChart_df['Reference year'] == 2017) & (sb_pieChart_df['Location indicator'] == 'Urban') & (sb_pieChart_df['Geography'] == 'Canada') & (sb_pieChart_df['Incorporation status'] == 'All businesses') & (sb_pieChart_df['North American Industry Classification System, NAICS'] == 'All industries')]
temp
# Out:
#       North American Industry Classification System, NAICS Geography  \
# 5                                         All industries      Canada
# 4622                                      All industries      Canada
# 9239                                      All industries      Canada
# 13856                                     All industries      Canada
# 18473                                     All industries      Canada
# 23090                                     All industries      Canada
# 27707                                     All industries      Canada
# 32324                                     All industries      Canada
# 36941                                     All industries      Canada
# 41558                                     All industries      Canada
# 46175                                     All industries      Canada
# 50792                                     All industries      Canada
# 55409                                     All industries      Canada
# ...

# %%
temp['value'].astype(float).sum()
# Out:
# 366.50000000000006

# %%
sb_revenue_value_3y
sb_revenue_value_3y[(sb_revenue_value_3y['Reference year'] == 2017) & (sb_revenue_value_3y['Location indicator'] == 'Urban') & (sb_revenue_value_3y['Geography'] == 'Canada') & (sb_revenue_value_3y['Incorporation status'] == 'All businesses') & (sb_revenue_value_3y['North American Industry Classification System, NAICS'] == 'All industries')]
# Out:
#     ID North American Industry Classification System, NAICS - code  \
# 6  6.0                                                  0
#
#   North American Industry Classification System, NAICS  Geography - code  \
# 6                                     All industries                 0.0
#
#   Geography  Location indicator - code Location indicator  \
# 6    Canada                        2.0              Urban
#
#    Incorporation status - code Incorporation status  Reference year  ...  \
# 6                          3.0       All businesses          2017.0  ...
#
#   Insurance, percent of businesses reporting Other indirect expenses  \
# 6                                       65.7                    48.3
#
#   Other indirect expenses, quality indicator  \
# 6                                          C
#
#   Other indirect expenses, percent of businesses reporting Total expenses  \
# 6                                               97.3                340.1
#
# ...

# %%
mb_Expense_barChart_df = mb_expenses_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year', 'Total expenses'
                        ]]

# %%
mb_Expense_barChart_df
mb_Expense_barChart_df = mb_Expense_barChart_df.rename(columns={'Total expenses':'Average revenue'})

# %%
mb_Expense_barChart_df.to_excel("Medium_Business_Expenses_barChart.xlsx")

# %%
sb_Expense_barChart_df = sb_revenue_value_3y[['North American Industry Classification System, NAICS','Geography',
                          'Location indicator', 'Incorporation status', 'Reference year', 'Total expenses'
                        ]]

# %%
# sb_revenue_value_3y
sb_Expense_barChart_df = sb_Expense_barChart_df.rename(columns={'Total expenses':'Average revenue'})

# %%
sb_Expense_barChart_df.to_excel("Small_Business_Expenses_barChart.xlsx")
